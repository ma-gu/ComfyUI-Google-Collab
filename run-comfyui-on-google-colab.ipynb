# %% [markdown]
# <a href="https://colab.research.google.com/github/ma-gu/ComfyUI-Google-Collab/blob/main/run-comfyui-on-google-colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Running ComfyUI in Google Colab
#
# To run ComfyUI in Google Colab, you need to enable GPU acceleration. Go to "Runtime" -> "Change runtime type" and select "GPU" as the hardware accelerator.

# %%
# Update package lists and install necessary packages
# !apt-get update
# !apt-get install -y wget aria2 libgl1-mesa-glx
# Out:
# Get:1 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:2 https://cli.github.com/packages stable InRelease [3,917 B]
# Get:3 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:6 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Hit:7 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:8 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:9 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:10 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [7,455 kB]
# Get:11 https://cli.github.com/packages stable/main amd64 Packages [355 B]
# Get:12 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:13 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [4,141 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:15 http://security.ubuntu.com/ubuntu jammy-security/multiverse amd64 Packages [84.1 kB]
# Get:16 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,313 kB]
# Get:17 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ Packages [101 kB]
# Get:18 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [2,849 kB]
# Get:19 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 Packages [43.4 kB]
# Get:20 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [3,131 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,616 kB]
# Get:22 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [4,480 kB]
# Get:23 http://archive.ubuntu.com/ubuntu jammy-updates/multiverse amd64 Packages [92.7 kB]
# Get:24 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [7,752 kB]
# Get:25 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [10.6 MB]
# Get:26 http://archive.ubuntu.com/ubuntu jammy-backports/main amd64 Packages [82.8 kB]
# Get:27 http://archive.ubuntu.com/ubuntu jammy-backports/universe amd64 Packages [35.6 kB]
# Fetched 44.2 MB in 6s (7,176 kB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# libgl1-mesa-glx is already the newest version (23.0.4-0ubuntu1~22.04.1).
# The following additional packages will be installed:
#   libaria2-0 libc-ares2
# The following NEW packages will be installed:
#   aria2 libaria2-0 libc-ares2
# The following packages will be upgraded:
#   wget
# 1 upgraded, 3 newly installed, 0 to remove and 161 not upgraded.
# Need to get 1,852 kB of archives.
# After this operation, 5,441 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 wget amd64 1.21.2-2ubuntu1.4 [339 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libc-ares2 amd64 1.18.1-1ubuntu0.22.04.3 [45.1 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libaria2-0 amd64 1.36.0-1 [1,086 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/universe amd64 aria2 amd64 1.36.0-1 [381 kB]
# Fetched 1,852 kB in 1s (2,034 kB/s)
# (Reading database ... 122403 files and directories currently installed.)
# Preparing to unpack .../wget_1.21.2-2ubuntu1.4_amd64.deb ...
# Unpacking wget (1.21.2-2ubuntu1.4) over (1.21.2-2ubuntu1.1) ...
# Selecting previously unselected package libc-ares2:amd64.
# Preparing to unpack .../libc-ares2_1.18.1-1ubuntu0.22.04.3_amd64.deb ...
# Unpacking libc-ares2:amd64 (1.18.1-1ubuntu0.22.04.3) ...
# Selecting previously unselected package libaria2-0:amd64.
# Preparing to unpack .../libaria2-0_1.36.0-1_amd64.deb ...
# Unpacking libaria2-0:amd64 (1.36.0-1) ...
# Selecting previously unselected package aria2.
# Preparing to unpack .../aria2_1.36.0-1_amd64.deb ...
# Unpacking aria2 (1.36.0-1) ...
# Setting up wget (1.21.2-2ubuntu1.4) ...
# Setting up libc-ares2:amd64 (1.18.1-1ubuntu0.22.04.3) ...
# Setting up libaria2-0:amd64 (1.36.0-1) ...
# Setting up aria2 (1.36.0-1) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero_v2.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link

# %%
# Clone the ComfyUI repository from GitHub
# !git clone https://github.com/comfyanonymous/ComfyUI.git
# Out:
# Cloning into 'ComfyUI'...
# remote: Enumerating objects: 43492, done.
# remote: Counting objects: 100% (19/19), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 43492 (delta 11), reused 7 (delta 7), pack-reused 43473 (from 2)
# Receiving objects: 100% (43492/43492), 84.22 MiB | 18.64 MiB/s, done.
# Resolving deltas: 100% (29520/29520), done.

# %%
# Change the current directory to ComfyUI and install required Python packages
# %cd ComfyUI
# !pip install -r requirements.txt
# Out:
# /content/ComfyUI
# Collecting comfyui-frontend-package==1.47.10 (from -r requirements.txt (line 1))
#   Downloading comfyui_frontend_package-1.47.10-py3-none-any.whl.metadata (118 bytes)
# Collecting comfyui-workflow-templates==0.11.17 (from -r requirements.txt (line 2))
#   Downloading comfyui_workflow_templates-0.11.17-py3-none-any.whl.metadata (24 kB)
# Collecting comfyui-embedded-docs==0.5.8 (from -r requirements.txt (line 3))
#   Downloading comfyui_embedded_docs-0.5.8-py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 4)) (2.11.0+cu128)
# Collecting torchsde (from -r requirements.txt (line 5))
#   Downloading torchsde-0.2.6-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 6)) (0.26.0+cu128)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 7)) (2.11.0+cu128)
# Requirement already satisfied: numpy>=1.25.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 8)) (2.0.2)
# Requirement already satisfied: einops in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 9)) (0.8.2)
# Requirement already satisfied: transformers>=4.50.3 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 10)) (5.13.1)
# Requirement already satisfied: tokenizers>=0.13.3 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 11)) (0.22.2)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 12)) (0.2.2)
# Requirement already satisfied: safetensors>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 13)) (0.8.0)
# Requirement already satisfied: aiohttp>=3.11.8 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 14)) (3.14.1)
# Requirement already satisfied: yarl>=1.18.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 15)) (1.24.2)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 16)) (6.0.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 17)) (11.3.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 18)) (1.16.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 19)) (4.67.3)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 20)) (5.9.5)
# Collecting alembic (from -r requirements.txt (line 21))
#   Downloading alembic-1.18.5-py3-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: SQLAlchemy>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 22)) (2.0.51)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 23)) (3.29.7)
# Collecting av>=16.0.0 (from -r requirements.txt (line 24))
#   Downloading av-18.0.0-cp311-abi3-manylinux_2_28_x86_64.whl.metadata (4.5 kB)
# Collecting comfy-kitchen==0.2.22 (from -r requirements.txt (line 25))
#   Downloading comfy_kitchen-0.2.22-cp312-abi3-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (7.5 kB)
# Collecting comfy-aimdo==0.4.10 (from -r requirements.txt (line 26))
#   Downloading comfy_aimdo-0.4.10-cp39-abi3-manylinux2010_x86_64.manylinux2014_x86_64.manylinux_2_12_x86_64.manylinux_2_17_x86_64.whl.metadata (4.2 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 27)) (2.32.4)
# Collecting simpleeval>=1.0.0 (from -r requirements.txt (line 28))
#   Downloading simpleeval-1.0.7-py3-none-any.whl.metadata (20 kB)
# Collecting blake3 (from -r requirements.txt (line 29))
#   Downloading blake3-1.0.9-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting kornia>=0.7.1 (from -r requirements.txt (line 32))
#   Downloading kornia-0.8.3-py3-none-any.whl.metadata (22 kB)
# Collecting spandrel (from -r requirements.txt (line 33))
#   Downloading spandrel-0.4.2-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: pydantic~=2.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 34)) (2.13.4)
# Collecting pydantic-settings~=2.0 (from -r requirements.txt (line 35))
#   Downloading pydantic_settings-2.14.2-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: PyOpenGL>=3.1.8 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 36)) (3.1.10)
# Collecting comfy-angle (from -r requirements.txt (line 37))
#   Downloading comfy_angle-0.1.0-py3-none-manylinux_2_28_x86_64.whl.metadata (1.6 kB)
# Collecting comfyui-workflow-templates-core==0.3.280 (from comfyui-workflow-templates==0.11.17->-r requirements.txt (line 2))
#   Downloading comfyui_workflow_templates_core-0.3.280-py3-none-any.whl.metadata (260 bytes)
# Collecting comfyui-workflow-templates-json==0.1.14 (from comfyui-workflow-templates==0.11.17->-r requirements.txt (line 2))
#   Downloading comfyui_workflow_templates_json-0.1.14-py3-none-any.whl.metadata (265 bytes)
# Collecting comfyui-workflow-templates-media-api==0.3.84 (from comfyui-workflow-templates==0.11.17->-r requirements.txt (line 2))
#   Downloading comfyui_workflow_templates_media_api-0.3.84-py3-none-any.whl.metadata (290 bytes)
# Collecting comfyui-workflow-templates-media-video==0.3.101 (from comfyui-workflow-templates==0.11.17->-r requirements.txt (line 2))
#   Downloading comfyui_workflow_templates_media_video-0.3.101-py3-none-any.whl.metadata (283 bytes)
# Collecting comfyui-workflow-templates-media-image==0.3.160 (from comfyui-workflow-templates==0.11.17->-r requirements.txt (line 2))
#   Downloading comfyui_workflow_templates_media_image-0.3.160-py3-none-any.whl.metadata (283 bytes)
# Collecting comfyui-workflow-templates-media-other==0.3.229 (from comfyui-workflow-templates==0.11.17->-r requirements.txt (line 2))
#   Downloading comfyui_workflow_templates_media_other-0.3.229-py3-none-any.whl.metadata (306 bytes)
# Collecting comfyui-workflow-templates-media-assets-01==0.1.10 (from comfyui-workflow-templates==0.11.17->-r requirements.txt (line 2))
#   Downloading comfyui_workflow_templates_media_assets_01-0.1.10-py3-none-any.whl.metadata (290 bytes)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 4)) (4.16.0)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 4)) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 4)) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 4)) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 4)) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 4)) (2025.3.0)
# Requirement already satisfied: cuda-toolkit==12.8.1 in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r requirements.txt (line 4)) (12.8.1)
# Requirement already satisfied: cuda-bindings<13,>=12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 4)) (12.9.7)
# Requirement already satisfied: nvidia-cudnn-cu12==9.19.0.56 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 4)) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 4)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.28.9 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 4)) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 4)) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 4)) (3.6.0)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r requirements.txt (line 4)) (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r requirements.txt (line 4)) (12.8.90)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r requirements.txt (line 4)) (11.3.3.83)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r requirements.txt (line 4)) (1.13.1.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r requirements.txt (line 4)) (12.8.90)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r requirements.txt (line 4)) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r requirements.txt (line 4)) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r requirements.txt (line 4)) (12.5.8.93)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r requirements.txt (line 4)) (12.8.93)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r requirements.txt (line 4)) (12.8.93)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r requirements.txt (line 4)) (12.8.90)
# Collecting trampoline>=0.1.2 (from torchsde->-r requirements.txt (line 5))
#   Downloading trampoline-0.1.2-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: huggingface-hub<2.0,>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.50.3->-r requirements.txt (line 10)) (1.23.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.50.3->-r requirements.txt (line 10)) (26.2)
# Requirement already satisfied: regex>=2025.10.22 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.50.3->-r requirements.txt (line 10)) (2025.11.3)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from transformers>=4.50.3->-r requirements.txt (line 10)) (0.26.8)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.11.8->-r requirements.txt (line 14)) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.11.8->-r requirements.txt (line 14)) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.11.8->-r requirements.txt (line 14)) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.11.8->-r requirements.txt (line 14)) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.11.8->-r requirements.txt (line 14)) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.11.8->-r requirements.txt (line 14)) (0.5.2)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.12/dist-packages (from yarl>=1.18.0->-r requirements.txt (line 15)) (3.18)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic->-r requirements.txt (line 21)) (1.1.3)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from SQLAlchemy>=2.0.0->-r requirements.txt (line 22)) (3.5.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->-r requirements.txt (line 27)) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->-r requirements.txt (line 27)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->-r requirements.txt (line 27)) (2026.6.17)
# Collecting kornia-rs>=0.1.9 (from kornia>=0.7.1->-r requirements.txt (line 32))
#   Downloading kornia_rs-0.1.14-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (15 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic~=2.0->-r requirements.txt (line 34)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.12/dist-packages (from pydantic~=2.0->-r requirements.txt (line 34)) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic~=2.0->-r requirements.txt (line 34)) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from pydantic-settings~=2.0->-r requirements.txt (line 35)) (1.2.2)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings<13,>=12.9.4->torch->-r requirements.txt (line 4)) (1.5.6)
# Requirement already satisfied: click<9.0.0,>=8.4.2 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers>=4.50.3->-r requirements.txt (line 10)) (8.4.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers>=4.50.3->-r requirements.txt (line 10)) (1.5.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers>=4.50.3->-r requirements.txt (line 10)) (0.28.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->-r requirements.txt (line 4)) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->-r requirements.txt (line 4)) (3.0.3)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->transformers>=4.50.3->-r requirements.txt (line 10)) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /usr/local/lib/python3.12/dist-packages (from typer->transformers>=4.50.3->-r requirements.txt (line 10)) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->transformers>=4.50.3->-r requirements.txt (line 10)) (0.0.4)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers>=4.50.3->-r requirements.txt (line 10)) (4.14.2)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers>=4.50.3->-r requirements.txt (line 10)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers>=4.50.3->-r requirements.txt (line 10)) (0.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer->transformers>=4.50.3->-r requirements.txt (line 10)) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer->transformers>=4.50.3->-r requirements.txt (line 10)) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer->transformers>=4.50.3->-r requirements.txt (line 10)) (0.1.2)
# Downloading comfyui_frontend_package-1.47.10-py3-none-any.whl (20.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.7/20.7 MB 78.8 MB/s eta 0:00:00
# Downloading comfyui_workflow_templates-0.11.17-py3-none-any.whl (10 kB)
# Downloading comfyui_embedded_docs-0.5.8-py3-none-any.whl (15.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.5/15.5 MB 105.5 MB/s eta 0:00:00
# Downloading comfy_kitchen-0.2.22-cp312-abi3-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (29.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.4/29.4 MB 14.6 MB/s eta 0:00:00
# Downloading comfy_aimdo-0.4.10-cp39-abi3-manylinux2010_x86_64.manylinux2014_x86_64.manylinux_2_12_x86_64.manylinux_2_17_x86_64.whl (346 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 346.8/346.8 kB 31.6 MB/s eta 0:00:00
# Downloading comfyui_workflow_templates_core-0.3.280-py3-none-any.whl (67 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.4/67.4 kB 7.0 MB/s eta 0:00:00
# Downloading comfyui_workflow_templates_json-0.1.14-py3-none-any.whl (2.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 106.1 MB/s eta 0:00:00
# Downloading comfyui_workflow_templates_media_api-0.3.84-py3-none-any.whl (100.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.1/100.1 MB 8.6 MB/s eta 0:00:00
# Downloading comfyui_workflow_templates_media_assets_01-0.1.10-py3-none-any.whl (17.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.4/17.4 MB 92.3 MB/s eta 0:00:00
# Downloading comfyui_workflow_templates_media_image-0.3.160-py3-none-any.whl (89.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.4/89.4 MB 9.1 MB/s eta 0:00:00
# Downloading comfyui_workflow_templates_media_other-0.3.229-py3-none-any.whl (89.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.1/89.1 MB 9.3 MB/s eta 0:00:00
# Downloading comfyui_workflow_templates_media_video-0.3.101-py3-none-any.whl (104.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.3/104.3 MB 8.5 MB/s eta 0:00:00
# Downloading torchsde-0.2.6-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 5.7 MB/s eta 0:00:00
# Downloading alembic-1.18.5-py3-none-any.whl (264 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.7/264.7 kB 27.7 MB/s eta 0:00:00
# Downloading av-18.0.0-cp311-abi3-manylinux_2_28_x86_64.whl (35.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.5/35.5 MB 64.0 MB/s eta 0:00:00
# Downloading simpleeval-1.0.7-py3-none-any.whl (18 kB)
# Downloading blake3-1.0.9-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (383 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 383.9/383.9 kB 37.3 MB/s eta 0:00:00
# Downloading kornia-0.8.3-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 80.5 MB/s eta 0:00:00
# Downloading spandrel-0.4.2-py3-none-any.whl (320 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 320.8/320.8 kB 32.5 MB/s eta 0:00:00
# Downloading pydantic_settings-2.14.2-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.7/61.7 kB 7.1 MB/s eta 0:00:00
# Downloading comfy_angle-0.1.0-py3-none-manylinux_2_28_x86_64.whl (4.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 93.8 MB/s eta 0:00:00
# Downloading kornia_rs-0.1.14-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 127.1 MB/s eta 0:00:00
# Downloading trampoline-0.1.2-py3-none-any.whl (5.2 kB)
# Installing collected packages: trampoline, simpleeval, kornia-rs, comfyui-workflow-templates-media-video, comfyui-workflow-templates-media-other, comfyui-workflow-templates-media-image, comfyui-workflow-templates-media-assets-01, comfyui-workflow-templates-media-api, comfyui-workflow-templates-json, comfyui-workflow-templates-core, comfyui-frontend-package, comfyui-embedded-docs, comfy-kitchen, comfy-angle, comfy-aimdo, blake3, av, comfyui-workflow-templates, alembic, pydantic-settings, torchsde, kornia, spandrel
# Successfully installed alembic-1.18.5 av-18.0.0 blake3-1.0.9 comfy-aimdo-0.4.10 comfy-angle-0.1.0 comfy-kitchen-0.2.22 comfyui-embedded-docs-0.5.8 comfyui-frontend-package-1.47.10 comfyui-workflow-templates-0.11.17 comfyui-workflow-templates-core-0.3.280 comfyui-workflow-templates-json-0.1.14 comfyui-workflow-templates-media-api-0.3.84 comfyui-workflow-templates-media-assets-01-0.1.10 comfyui-workflow-templates-media-image-0.3.160 comfyui-workflow-templates-media-other-0.3.229 comfyui-workflow-templates-media-video-0.3.101 kornia-0.8.3 kornia-rs-0.1.14 pydantic-settings-2.14.2 simpleeval-1.0.7 spandrel-0.4.2 torchsde-0.2.6 trampoline-0.1.2

# %%
# Install the pinggy library for creating public URLs
# !pip install pinggy
#!pip install "triton==3.2.*"
# !pip install sageattention
# Out:
# Collecting pinggy
#   Downloading pinggy-0.3.0-cp36-abi3-manylinux_2_28_x86_64.whl.metadata (2.9 kB)
# Downloading pinggy-0.3.0-cp36-abi3-manylinux_2_28_x86_64.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 98.6 MB/s eta 0:00:00
# Installing collected packages: pinggy
# Successfully installed pinggy-0.3.0
# Collecting sageattention
#   Downloading sageattention-1.0.6-py3-none-any.whl.metadata (5.6 kB)
# Downloading sageattention-1.0.6-py3-none-any.whl (20 kB)
# Installing collected packages: sageattention
# Successfully installed sageattention-1.0.6

# %%
# Clone ComfyUI custom nodes
# Install ComfyUI custom nodes
import pathlib, subprocess

root = pathlib.Path("/content/ComfyUI")
custom = root / "custom_nodes"
custom.mkdir(parents=True, exist_ok=True)

# %cd /content/ComfyUI/custom_nodes

repos = [
    "https://github.com/Alectriciti/comfyui-adaptiveprompts.git",
    "https://github.com/scottmudge/ComfyUI-NAG.git",
    "https://github.com/melMass/comfy_mtb.git",
    "https://github.com/rgthree/rgthree-comfy.git",
    "https://github.com/kijai/ComfyUI-WanVideoWrapper.git",
    "https://github.com/Kosinkadink/ComfyUI-VideoHelperSuite.git",
    "https://github.com/Fannovel16/ComfyUI-Frame-Interpolation.git",
    "https://github.com/kijai/ComfyUI-KJNodes.git",
    "https://github.com/yolain/ComfyUI-Easy-Use.git",
    "https://github.com/Suzie1/ComfyUI_Comfyroll_CustomNodes.git",
    "https://github.com/city96/ComfyUI-GGUF.git",
    "https://github.com/Smirnov75/ComfyUI-mxToolkit.git",
    "https://github.com/Comfy-Org/ComfyUI-Manager.git",
    "https://github.com/Artificial-Sweetener/comfyui-WhiteRabbit.git",
    "https://github.com/pythongosssss/ComfyUI-Custom-Scripts.git",
]

# Клонирование
for url in repos:
    name = url.rsplit("/", 1)[-1].replace(".git", "")
    if (custom / name).exists():
        print(f"Skip, already exists: {name}")
        continue
    subprocess.run(["git", "clone", url], check=True)

# Установка requirements (если есть)
for url in repos:
    name = url.rsplit("/", 1)[-1].replace(".git", "")
    req = custom / name / "requirements.txt"
    if req.exists():
        print(f"Installing requirements for {name}")
        subprocess.run(["pip", "install", "-r", str(req)], check=True)
    else:
        print(f"No requirements.txt for {name}, skip")
# Out:
# /content/ComfyUI/custom_nodes
# No requirements.txt for comfyui-adaptiveprompts, skip
# No requirements.txt for ComfyUI-NAG, skip
# Installing requirements for comfy_mtb
# Installing requirements for rgthree-comfy
# Installing requirements for ComfyUI-WanVideoWrapper
# Installing requirements for ComfyUI-VideoHelperSuite
# No requirements.txt for ComfyUI-Frame-Interpolation, skip
# Installing requirements for ComfyUI-KJNodes
# Installing requirements for ComfyUI-Easy-Use
# No requirements.txt for ComfyUI_Comfyroll_CustomNodes, skip
# Installing requirements for ComfyUI-GGUF
# No requirements.txt for ComfyUI-mxToolkit, skip
# Installing requirements for ComfyUI-Manager
# Installing requirements for comfyui-WhiteRabbit
# No requirements.txt for ComfyUI-Custom-Scripts, skip

# %%
# Download Wan / GGUF / LoRA models for ComfyUI (Civitai через ?token=)

import os
import pathlib
import subprocess
from urllib.parse import urlparse, parse_qs, urlencode, urlunparse
from google.colab import userdata

# Берём токен из окружения (Colab Secrets / Variables)
#CIVITAI_TOKEN = os.environ.get("CIVITAI_TOKEN", "").strip()
CIVITAI_TOKEN = userdata.get("CIVITAI_TOKEN").strip()
if not CIVITAI_TOKEN:
    print("WARNING: CIVITAI_TOKEN не найден в os.environ – ссылки Civitai, требующие логин, могут не скачаться.")

root = pathlib.Path("/content/ComfyUI")

paths = {
    "vae": root / "models" / "vae",
    "text_encoders": root / "models" / "text_encoders",
    "diffusion": root / "models" / "diffusion_models",
    "loras": root / "models" / "loras",
    "clip_vision": root / "models" / "clip_vision",
    "upscale_models": root / "models" / "upscale_models",
}

for p in paths.values():
    p.mkdir(parents=True, exist_ok=True)

downloads = [
    # Wan VAE
    (
        "https://huggingface.co/OreX/Models/resolve/main/WAN/wan_2.1_vae.safetensors?download=true",
        paths["vae"] / "wan_2.1_vae.safetensors",
    ),
    # umt5 text encoder
    (
        "https://huggingface.co/OreX/Models/resolve/main/WAN/umt5_xxl_fp8_e4m3fn_scaled.safetensors?download=true",
        paths["text_encoders"] / "umt5_xxl_fp8_e4m3fn_scaled.safetensors",
    ),
    # Smooth Mix Wan 2.2 14B I2V 2.0 High (Civitai)
    (
        "https://civitai.red/api/download/models/2513182?fileId=2460270",
        paths["diffusion"] / "SmoothMix_Wan2.2_14B_I2V_2.0_High.safetensors",
    ),
    # Smooth Mix Wan 2.2 14B I2V 2.0 Low (Civitai)
    (
        "https://civitai.red/api/download/models/2513186?fileId=2460676",
        paths["diffusion"] / "SmoothMix_Wan2.2_14B_I2V_2.0_Low.safetensors",
    ),
    # GGUF High
    (
        #"https://huggingface.co/QuantStack/Wan2.2-I2V-A14B-GGUF/resolve/main/HighNoise/Wan2.2-I2V-A14B-HighNoise-Q2_K.gguf?download=true",
        None,
        paths["diffusion"] / "Wan2.2-I2V-A14B-HighNoise-Q2_K.gguf",
    ),
    # GGUF Low
    (
        #"https://huggingface.co/QuantStack/Wan2.2-I2V-A14B-GGUF/resolve/main/LowNoise/Wan2.2-I2V-A14B-LowNoise-Q2_K.gguf?download=true",
        None,
        paths["diffusion"] / "Wan2.2-I2V-A14B-LowNoise-Q2_K.gguf",
    ),
    # LoRA lightx2v
    (
        "https://huggingface.co/Kijai/WanVideo_comfy/resolve/709844db75d2e15582cf204e9a0b5e12b23a35dd/Lightx2v/lightx2v_I2V_14B_480p_cfg_step_distill_rank128_bf16.safetensors?download=true",
        paths["loras"] / "lightx2v_I2V_14B_480p_cfg_step_distill_rank128_bf16.safetensors",
    ),
    # clip_vision
    (
        "https://huggingface.co/OreX/Models/resolve/main/WAN/clip_vision_h.safetensors?download=true",
        paths["clip_vision"] / "clip_vision_h.safetensors",
    ),
    # upscale models
    (
        "https://huggingface.co/utnah/esrgan/resolve/main/4x-AnimeSharp.pth?download=true",
        paths["upscale_models"] / "4x-AnimeSharp.pth",
    ),
]

def add_token_to_civitai_url(url: str, token: str) -> str:
    if not token:
        return url
    if "civitai.com" not in url and "civitai.red" not in url:
        return url

    parsed = urlparse(url)
    qs = parse_qs(parsed.query)
    # не перезаписываем, если токен уже вставлен руками
    if "token" in qs:
        return url

    qs["token"] = [token]
    new_query = urlencode(qs, doseq=True)
    new_parsed = parsed._replace(query=new_query)
    return urlunparse(new_parsed)

def build_aria2_cmd(url: str, out_path: pathlib.Path):
    # Для civitai добавляем token в сам URL
    url_with_token = add_token_to_civitai_url(url, CIVITAI_TOKEN)

    cmd = [
        "aria2c",
        "-x", "16",
        "-s", "16",
        "-o", out_path.name,
        "-d", str(out_path.parent),
        url_with_token,
    ]
    return cmd

for url, out_path in downloads:
    if out_path.exists():
        print(f"Already exists, skip: {out_path}")
        continue

    out_path.parent.mkdir(parents=True, exist_ok=True)

    if url is None:
        print(f"Creating empty file: {out_path}")
        out_path.touch()
        continue

    print(f"\nDownloading {url} -> {out_path}")
    cmd = build_aria2_cmd(url, out_path)
    print("Command:", " ".join(cmd))
    try:
        # Важно: для ссылок с '&' aria2c уже видит всё как один аргумент,
        # т.к. мы не даём shell и передаём список аргументов subprocess-у.
        subprocess.run(cmd, check=True)
    except subprocess.CalledProcessError as e:
        print(f"Download failed for {url}: {e}")
# Out:
# Downloading https://huggingface.co/OreX/Models/resolve/main/WAN/wan_2.1_vae.safetensors?download=true -> /content/ComfyUI/models/vae/wan_2.1_vae.safetensors
# Command: aria2c -x 16 -s 16 -o wan_2.1_vae.safetensors -d /content/ComfyUI/models/vae https://huggingface.co/OreX/Models/resolve/main/WAN/wan_2.1_vae.safetensors?download=true
#
# Downloading https://huggingface.co/OreX/Models/resolve/main/WAN/umt5_xxl_fp8_e4m3fn_scaled.safetensors?download=true -> /content/ComfyUI/models/text_encoders/umt5_xxl_fp8_e4m3fn_scaled.safetensors
# Command: aria2c -x 16 -s 16 -o umt5_xxl_fp8_e4m3fn_scaled.safetensors -d /content/ComfyUI/models/text_encoders https://huggingface.co/OreX/Models/resolve/main/WAN/umt5_xxl_fp8_e4m3fn_scaled.safetensors?download=true
#
# Downloading https://civitai.red/api/download/models/2513182?fileId=2460270 -> /content/ComfyUI/models/diffusion_models/SmoothMix_Wan2.2_14B_I2V_2.0_High.safetensors
# Command: aria2c -x 16 -s 16 -o SmoothMix_Wan2.2_14B_I2V_2.0_High.safetensors -d /content/ComfyUI/models/diffusion_models https://civitai.red/api/download/models/2513182?fileId=2460270&token=cb2721923059a011c1fce7556e35751a
#
# Downloading https://civitai.red/api/download/models/2513186?fileId=2460676 -> /content/ComfyUI/models/diffusion_models/SmoothMix_Wan2.2_14B_I2V_2.0_Low.safetensors
# Command: aria2c -x 16 -s 16 -o SmoothMix_Wan2.2_14B_I2V_2.0_Low.safetensors -d /content/ComfyUI/models/diffusion_models https://civitai.red/api/download/models/2513186?fileId=2460676&token=cb2721923059a011c1fce7556e35751a
# Creating empty file: /content/ComfyUI/models/diffusion_models/Wan2.2-I2V-A14B-HighNoise-Q2_K.gguf
# Creating empty file: /content/ComfyUI/models/diffusion_models/Wan2.2-I2V-A14B-LowNoise-Q2_K.gguf
#
# Downloading https://huggingface.co/Kijai/WanVideo_comfy/resolve/709844db75d2e15582cf204e9a0b5e12b23a35dd/Lightx2v/lightx2v_I2V_14B_480p_cfg_step_distill_rank128_bf16.safetensors?download=true -> /content/ComfyUI/models/loras/lightx2v_I2V_14B_480p_cfg_step_distill_rank128_bf16.safetensors
# Command: aria2c -x 16 -s 16 -o lightx2v_I2V_14B_480p_cfg_step_distill_rank128_bf16.safetensors -d /content/ComfyUI/models/loras https://huggingface.co/Kijai/WanVideo_comfy/resolve/709844db75d2e15582cf204e9a0b5e12b23a35dd/Lightx2v/lightx2v_I2V_14B_480p_cfg_step_distill_rank128_bf16.safetensors?download=true
#
# Downloading https://huggingface.co/OreX/Models/resolve/main/WAN/clip_vision_h.safetensors?download=true -> /content/ComfyUI/models/clip_vision/clip_vision_h.safetensors
# Command: aria2c -x 16 -s 16 -o clip_vision_h.safetensors -d /content/ComfyUI/models/clip_vision https://huggingface.co/OreX/Models/resolve/main/WAN/clip_vision_h.safetensors?download=true
#
# Downloading https://huggingface.co/utnah/esrgan/resolve/main/4x-AnimeSharp.pth?download=true -> /content/ComfyUI/models/upscale_models/4x-AnimeSharp.pth
# Command: aria2c -x 16 -s 16 -o 4x-AnimeSharp.pth -d /content/ComfyUI/models/upscale_models https://huggingface.co/utnah/esrgan/resolve/main/4x-AnimeSharp.pth?download=true

# %%
# Start a pinggy tunnel to forward traffic from a public URL to localhost:8188
import pinggy
tunnel1 = pinggy.start_tunnel(
    forwardto="localhost:8188",
)

# Print the URLs of the started tunnel
print(f"Tunnel1 started - URLs: {tunnel1.urls}")
# Out:
# Tunnel1 started - URLs: ['http://phaml-34-12-225-42.run.pinggy-free.link', 'http://rsira-34-12-225-42.free.pinggy.net', 'https://phaml-34-12-225-42.run.pinggy-free.link', 'https://rsira-34-12-225-42.free.pinggy.net']

# %%
# Run the main ComfyUI application, listening on all network interfaces
# %cd /content/ComfyUI
#!nohup python main.py --listen 0.0.0.0 > comfyui.log 2>&1 &
# !python main.py --listen 0.0.0.0
#!python main.py --use-sage-attention --listen 0.0.0.0
# Out:
# /content/ComfyUI
# [INFO] setup plugin alembic.autogenerate.schemas
# [INFO] setup plugin alembic.autogenerate.tables
# [INFO] setup plugin alembic.autogenerate.types
# [INFO] setup plugin alembic.autogenerate.constraints
# [INFO] setup plugin alembic.autogenerate.defaults
# [INFO] setup plugin alembic.autogenerate.comments
# [START] Security scan
# [INFO] [ComfyUI-Manager] Using `uv` as Python module for pip operations.
# Using Python 3.12.13 environment at: /usr
# [DONE] Security scan
# ## ComfyUI-Manager: installing dependencies done.
# ** ComfyUI startup time: 2026-07-25 07:25:34.285
# ** Platform: Linux
# ** Python version: 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# ** Python executable: /usr/bin/python3
# ** ComfyUI Path: /content/ComfyUI
# ** ComfyUI Base Folder Path: /content/ComfyUI
# ** User directory: /content/ComfyUI/user
# ** ComfyUI-Manager config path: /content/ComfyUI/user/__manager/config.ini
# ** Log path: /content/ComfyUI/user/comfyui.log
# Using Python 3.12.13 environment at: /usr
# Using Python 3.12.13 environment at: /usr
# [INFO]
# Prestartup times for custom nodes:
# [INFO]    0.0 seconds: /content/ComfyUI/custom_nodes/rgthree-comfy
# [INFO]    0.0 seconds: /content/ComfyUI/custom_nodes/ComfyUI-Easy-Use
# [INFO]    1.4 seconds: /content/ComfyUI/custom_nodes/ComfyUI-Manager
# [INFO]
# [WARNING] WARNING: You need pytorch with cu130 or higher to use optimized CUDA operations.
# [INFO] Found comfy_kitchen backend triton: {'available': True, 'disabled': True, 'unavailable_reason': None, 'capabilities': ['adaln', 'apply_rope', 'apply_rope1', 'apply_rope_split_half', 'apply_rope_split_half1', 'dequantize_nvfp4', 'dequantize_per_tensor_fp8', 'int8_linear', 'quantize_and_rotate_rowwise', 'quantize_int8_rowwise', 'quantize_mxfp8', 'quantize_nvfp4', 'quantize_per_tensor_fp8']}
# [INFO] Found comfy_kitchen backend eager: {'available': True, 'disabled': False, 'unavailable_reason': None, 'capabilities': ['adaln', 'apply_rope', 'apply_rope1', 'apply_rope_split_half', 'apply_rope_split_half1', 'convrot_w4a4_linear', 'dequantize_convrot_w4a4_weight', 'dequantize_int8_convrot_weight', 'dequantize_int8_convrot_weight_dtype', 'dequantize_int8_simple', 'dequantize_int8_simple_dtype', 'dequantize_mxfp8', 'dequantize_nvfp4', 'dequantize_per_tensor_fp8', 'gemv_awq_w4a16', 'int8_linear', 'prepare_int4_weight_for_int8_linear', 'quantize_and_rotate_rowwise', 'quantize_convrot_w4a4_weight', 'quantize_int8_convrot_weight', 'quantize_int8_rowwise', 'quantize_int8_tensorwise', 'quantize_mxfp8', 'quantize_nvfp4', 'quantize_per_tensor_fp8', 'quantize_svdquant_w4a4', 'rms_rope', 'rms_rope1', 'rms_rope_split_half', 'rms_rope_split_half1', 'scaled_mm_mxfp8', 'scaled_mm_nvfp4', 'scaled_mm_svdquant_w4a4', 'stochastic_rounding_fp8']}
# [INFO] Found comfy_kitchen backend cuda: {'available': True, 'disabled': True, 'unavailable_reason': None, 'capabilities': ['adaln', 'apply_rope', 'apply_rope1', 'apply_rope_split_half', 'apply_rope_split_half1', 'convrot_w4a4_linear', 'dequantize_convrot_w4a4_weight', 'dequantize_int8_convrot_weight', 'dequantize_int8_convrot_weight_dtype', 'dequantize_int8_simple', 'dequantize_int8_simple_dtype', 'dequantize_nvfp4', 'dequantize_per_tensor_fp8', 'gemv_awq_w4a16', 'int8_linear', 'prepare_int4_weight_for_int8_linear', 'quantize_and_rotate_rowwise', 'quantize_convrot_w4a4_weight', 'quantize_int8_convrot_weight', 'quantize_int8_rowwise', 'quantize_int8_tensorwise', 'quantize_mxfp8', 'quantize_nvfp4', 'quantize_per_tensor_fp8', 'quantize_svdquant_w4a4', 'rms_rope', 'rms_rope1', 'rms_rope_split_half', 'rms_rope_split_half1', 'scaled_mm_nvfp4', 'scaled_mm_svdquant_w4a4', 'stochastic_rounding_fp8']}
# [INFO] Checkpoint files will always be loaded safely.
# [INFO] Total VRAM 14913 MB, total RAM 12976 MB
# [INFO] pytorch version: 2.11.0+cu128
# [INFO] Set vram state to: NORMAL_VRAM
# [INFO] Device: cuda:0 Tesla T4 : cudaMallocAsync
# [INFO] Using async weight offloading with 2 streams
# [INFO] Enabled pinned memory 11677.0
# [INFO] Using pytorch attention
# aimdo: /project/src-posix/cuda-funchooks.c:52:DEBUG:aimdo_setup_hooks: hooks successfully installed
# aimdo: /project/src/control.c:247:INFO:comfy-aimdo inited for GPU: Tesla T4 (VRAM: 14912 MB)
# [INFO] DynamicVRAM support detected and enabled
# [INFO] Python version: 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# [INFO] ComfyUI version: 0.28.0
# [INFO] comfy-aimdo version: 0.4.10
# [INFO] comfy-kitchen version: 0.2.22
# [INFO] comfyui-frontend-package version: 1.47.10
# [INFO] comfyui-workflow-templates version: 0.11.17
# [INFO] comfyui-embedded-docs version: 0.5.8
# [INFO] comfy-kitchen version: 0.2.22
# [INFO] comfy-aimdo version: 0.4.10
# [INFO] [Prompt Server] web root: /usr/local/lib/python3.12/dist-packages/comfyui_frontend_package/static
# [INFO] Asset seeder disabled
# [INFO] No OpenGL_accelerate module loaded: No module named 'OpenGL_accelerate'
# [INFO] NumExpr defaulting to 2 threads.
# [WARNING] WanVideoWrapper WARNING: FantasyPortrait nodes not available: No module named 'onnx'
#
# [rgthree-comfy] Loaded 48 epic nodes. 🎉
#
# [rgthree-comfy] ComfyUI's new Node 2.0 rendering may be incompatible with some rgthree-comfy nodes and features, breaking some rendering as well as losing the ability to access a node's properties (a vital part of many nodes). It also appears to run MUCH more slowly spiking CPU usage and causing jankiness and unresponsiveness, especially with large workflows. Personally I am not planning to use the new Nodes 2.0 and, unfortunately, am not able to invest the time to investigate and overhaul rgthree-comfy where needed. If you have issues when Nodes 2.0 is enabled, I'd urge you to switch it off as well and join me in hoping ComfyUI is not planning to deprecate the existing, stable canvas rendering all together.
#
# Flax classes are deprecated and will be removed in Diffusers v0.40.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Flax classes are deprecated and will be removed in Diffusers v0.40.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# [ComfyUI-Easy-Use] server: v1.3.7 Loaded
# [ComfyUI-Easy-Use] web root: /content/ComfyUI/custom_nodes/ComfyUI-Easy-Use/web_version/v2 Loaded
# [INFO] ### Loading: ComfyUI-Manager (V3.41)
# [INFO] [ComfyUI-Manager] network_mode: public
# [INFO] [ComfyUI-Manager] ComfyUI per-queue preview override detected (PR #11261). Manager's preview method feature is disabled. Use ComfyUI's --preview-method CLI option or 'Settings > Execution > Live preview method'.
# [INFO] ### ComfyUI Version: v0.28.0-39-g45ffd543 | Released on '2026-07-24'
# [INFO] ComfyUI-GGUF: Allowing full torch compile
# [INFO] [ComfyUI-Manager] default cache updated: https://raw.githubusercontent.com/ltdrdata/ComfyUI-Manager/main/model-list.json
# [INFO] [ComfyUI-Manager] default cache updated: https://raw.githubusercontent.com/ltdrdata/ComfyUI-Manager/main/custom-node-list.json
# [INFO] [ComfyUI-Manager] default cache updated: https://raw.githubusercontent.com/ltdrdata/ComfyUI-Manager/main/extension-node-map.json
# ------------------------------------------
# Comfyroll Studio v1.76 :  175 Nodes Loaded
# ------------------------------------------
# ** For changes, please see patch notes at https://github.com/Suzie1/ComfyUI_Comfyroll_CustomNodes/blob/main/Patch_Notes.md
# ** For help, please see the wiki at https://github.com/Suzie1/ComfyUI_Comfyroll_CustomNodes/wiki
# ------------------------------------------[INFO] [ComfyUI-Manager] default cache updated: https://raw.githubusercontent.com/ltdrdata/ComfyUI-Manager/main/github-stats.json
#
# [INFO] [ComfyUI-Manager] default cache updated: https://raw.githubusercontent.com/ltdrdata/ComfyUI-Manager/main/alter-list.json
# FETCH ComfyRegistry Data: 5/164
# [/content/ComfyUI/custom_nodes/comfy_mtb] | INFO -> loaded 111 nodes successfuly
# [/content/ComfyUI/custom_nodes/comfy_mtb] | INFO -> Some nodes (2) could not be loaded. This can be ignored, but go to http://None:8188/mtb if you want more information.
# [INFO]
# Import times for custom nodes:
# [INFO]    0.0 seconds: /content/ComfyUI/custom_nodes/websocket_image_save.py
# [INFO]    0.0 seconds: /content/ComfyUI/custom_nodes/ComfyUI-mxToolkit
# [INFO]    0.0 seconds: /content/ComfyUI/custom_nodes/ComfyUI-Custom-Scripts
# [INFO]    0.0 seconds: /content/ComfyUI/custom_nodes/ComfyUI-NAG
# [INFO]    0.0 seconds: /content/ComfyUI/custom_nodes/comfyui-adaptiveprompts
# [INFO]    0.0 seconds: /content/ComfyUI/custom_nodes/ComfyUI-GGUF
# [INFO]    0.0 seconds: /content/ComfyUI/custom_nodes/ComfyUI-Frame-Interpolation
# [INFO]    0.0 seconds: /content/ComfyUI/custom_nodes/comfyui-WhiteRabbit
# [INFO]    0.0 seconds: /content/ComfyUI/custom_nodes/rgthree-comfy
# [INFO]    0.0 seconds: /content/ComfyUI/custom_nodes/ComfyUI-KJNodes
# [INFO]    0.1 seconds: /content/ComfyUI/custom_nodes/ComfyUI-Manager
# [INFO]    0.7 seconds: /content/ComfyUI/custom_nodes/ComfyUI-VideoHelperSuite
# [INFO]    1.2 seconds: /content/ComfyUI/custom_nodes/ComfyUI_Comfyroll_CustomNodes
# [INFO]    1.5 seconds: /content/ComfyUI/custom_nodes/ComfyUI-Easy-Use
# [INFO]    4.2 seconds: /content/ComfyUI/custom_nodes/ComfyUI-WanVideoWrapper
# [INFO]    4.4 seconds: /content/ComfyUI/custom_nodes/comfy_mtb
# [INFO]
# [INFO] Context impl SQLiteImpl.
# [INFO] Will assume non-transactional DDL.
# [INFO] Using RAM pressure cache.
# [INFO] Starting server
#
# [INFO] To see the GUI go to: http://0.0.0.0:8188
# FETCH ComfyRegistry Data: 10/164
# FETCH ComfyRegistry Data: 15/164
# FETCH ComfyRegistry Data: 20/164
# FETCH ComfyRegistry Data: 25/164
# [INFO] got prompt
# FETCH ComfyRegistry Data: 30/164
# [INFO] Found quantization metadata version 1
# [INFO] Using MixedPrecisionOps for text encoder
# [INFO] CLIP/text encoder model load device: cuda:0, offload device: cpu, current: cpu, dtype: torch.float16
# [INFO] Using pytorch attention in VAE
# [INFO] Using pytorch attention in VAE
# [INFO] VAE load device: cuda:0, offload device: cpu, dtype: torch.float16
# [INFO] Found quantization metadata version 1
# [INFO] Detected mixed precision quantization
# [INFO] Using mixed precision operations
# [INFO] Native ops: convrot_w4a4, int8_tensorwise , emulated ops: mxfp8, nvfp4, float8_e5m2, float8_e4m3fn
# [INFO] model weight dtype torch.float16, manual cast: torch.float16
# [INFO] model_type FLOW
# [INFO] Using sage attention mode: auto
# [WARNING] lora key not loaded: diffusion_model.blocks.0.cross_attn.k_img.diff_b
# [WARNING] lora key not loaded: diffusion_model.blocks.0.cross_attn.k_img.lora_down.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.0.cross_attn.k_img.lora_up.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.0.cross_attn.norm_k_img.diff
# [WARNING] lora key not loaded: diffusion_model.blocks.0.cross_attn.v_img.diff_b
# [WARNING] lora key not loaded: diffusion_model.blocks.0.cross_attn.v_img.lora_down.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.0.cross_attn.v_img.lora_up.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.1.cross_attn.k_img.diff_b
# [WARNING] lora key not loaded: diffusion_model.blocks.1.cross_attn.k_img.lora_down.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.1.cross_attn.k_img.lora_up.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.1.cross_attn.norm_k_img.diff
# [WARNING] lora key not loaded: diffusion_model.blocks.1.cross_attn.v_img.diff_b
# [WARNING] lora key not loaded: diffusion_model.blocks.1.cross_attn.v_img.lora_down.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.1.cross_attn.v_img.lora_up.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.10.cross_attn.k_img.diff_b
# [WARNING] lora key not loaded: diffusion_model.blocks.10.cross_attn.k_img.lora_down.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.10.cross_attn.k_img.lora_up.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.10.cross_attn.norm_k_img.diff
# [WARNING] lora key not loaded: diffusion_model.blocks.10.cross_attn.v_img.diff_b
# [WARNING] lora key not loaded: diffusion_model.blocks.10.cross_attn.v_img.lora_down.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.10.cross_attn.v_img.lora_up.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.11.cross_attn.k_img.diff_b
# [WARNING] lora key not loaded: diffusion_model.blocks.11.cross_attn.k_img.lora_down.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.11.cross_attn.k_img.lora_up.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.11.cross_attn.norm_k_img.diff
# [WARNING] lora key not loaded: diffusion_model.blocks.11.cross_attn.v_img.diff_b
# [WARNING] lora key not loaded: diffusion_model.blocks.11.cross_attn.v_img.lora_down.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.11.cross_attn.v_img.lora_up.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.12.cross_attn.k_img.diff_b
# [WARNING] lora key not loaded: diffusion_model.blocks.12.cross_attn.k_img.lora_down.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.12.cross_attn.k_img.lora_up.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.12.cross_attn.norm_k_img.diff
# [WARNING] lora key not loaded: diffusion_model.blocks.12.cross_attn.v_img.diff_b
# [WARNING] lora key not loaded: diffusion_model.blocks.12.cross_attn.v_img.lora_down.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.12.cross_attn.v_img.lora_up.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.13.cross_attn.k_img.diff_b
# [WARNING] lora key not loaded: diffusion_model.blocks.13.cross_attn.k_img.lora_down.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.13.cross_attn.k_img.lora_up.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.13.cross_attn.norm_k_img.diff
# [WARNING] lora key not loaded: diffusion_model.blocks.13.cross_attn.v_img.diff_b
# [WARNING] lora key not loaded: diffusion_model.blocks.13.cross_attn.v_img.lora_down.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.13.cross_attn.v_img.lora_up.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.14.cross_attn.k_img.diff_b
# [WARNING] lora key not loaded: diffusion_model.blocks.14.cross_attn.k_img.lora_down.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.14.cross_attn.k_img.lora_up.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.14.cross_attn.norm_k_img.diff
# [WARNING] lora key not loaded: diffusion_model.blocks.14.cross_attn.v_img.diff_b
# [WARNING] lora key not loaded: diffusion_model.blocks.14.cross_attn.v_img.lora_down.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.14.cross_attn.v_img.lora_up.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.15.cross_attn.k_img.diff_b
# [WARNING] lora key not loaded: diffusion_model.blocks.15.cross_attn.k_img.lora_down.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.15.cross_attn.k_img.lora_up.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.15.cross_attn.norm_k_img.diff
# [WARNING] lora key not loaded: diffusion_model.blocks.15.cross_attn.v_img.diff_b
# [WARNING] lora key not loaded: diffusion_model.blocks.15.cross_attn.v_img.lora_down.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.15.cross_attn.v_img.lora_up.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.16.cross_attn.k_img.diff_b
# [WARNING] lora key not loaded: diffusion_model.blocks.16.cross_attn.k_img.lora_down.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.16.cross_attn.k_img.lora_up.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.16.cross_attn.norm_k_img.diff
# [WARNING] lora key not loaded: diffusion_model.blocks.16.cross_attn.v_img.diff_b
# [WARNING] lora key not loaded: diffusion_model.blocks.16.cross_attn.v_img.lora_down.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.16.cross_attn.v_img.lora_up.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.17.cross_attn.k_img.diff_b
# [WARNING] lora key not loaded: diffusion_model.blocks.17.cross_attn.k_img.lora_down.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.17.cross_attn.k_img.lora_up.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.17.cross_attn.norm_k_img.diff
# [WARNING] lora key not loaded: diffusion_model.blocks.17.cross_attn.v_img.diff_b
# [WARNING] lora key not loaded: diffusion_model.blocks.17.cross_attn.v_img.lora_down.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.17.cross_attn.v_img.lora_up.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.18.cross_attn.k_img.diff_b
# [WARNING] lora key not loaded: diffusion_model.blocks.18.cross_attn.k_img.lora_down.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.18.cross_attn.k_img.lora_up.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.18.cross_attn.norm_k_img.diff
# [WARNING] lora key not loaded: diffusion_model.blocks.18.cross_attn.v_img.diff_b
# [WARNING] lora key not loaded: diffusion_model.blocks.18.cross_attn.v_img.lora_down.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.18.cross_attn.v_img.lora_up.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.19.cross_attn.k_img.diff_b
# [WARNING] lora key not loaded: diffusion_model.blocks.19.cross_attn.k_img.lora_down.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.19.cross_attn.k_img.lora_up.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.19.cross_attn.norm_k_img.diff
# [WARNING] lora key not loaded: diffusion_model.blocks.19.cross_attn.v_img.diff_b
# [WARNING] lora key not loaded: diffusion_model.blocks.19.cross_attn.v_img.lora_down.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.19.cross_attn.v_img.lora_up.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.2.cross_attn.k_img.diff_b
# [WARNING] lora key not loaded: diffusion_model.blocks.2.cross_attn.k_img.lora_down.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.2.cross_attn.k_img.lora_up.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.2.cross_attn.norm_k_img.diff
# [WARNING] lora key not loaded: diffusion_model.blocks.2.cross_attn.v_img.diff_b
# [WARNING] lora key not loaded: diffusion_model.blocks.2.cross_attn.v_img.lora_down.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.2.cross_attn.v_img.lora_up.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.20.cross_attn.k_img.diff_b
# [WARNING] lora key not loaded: diffusion_model.blocks.20.cross_attn.k_img.lora_down.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.20.cross_attn.k_img.lora_up.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.20.cross_attn.norm_k_img.diff
# [WARNING] lora key not loaded: diffusion_model.blocks.20.cross_attn.v_img.diff_b
# [WARNING] lora key not loaded: diffusion_model.blocks.20.cross_attn.v_img.lora_down.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.20.cross_attn.v_img.lora_up.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.21.cross_attn.k_img.diff_b
# [WARNING] lora key not loaded: diffusion_model.blocks.21.cross_attn.k_img.lora_down.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.21.cross_attn.k_img.lora_up.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.21.cross_attn.norm_k_img.diff
# [WARNING] lora key not loaded: diffusion_model.blocks.21.cross_attn.v_img.diff_b
# [WARNING] lora key not loaded: diffusion_model.blocks.21.cross_attn.v_img.lora_down.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.21.cross_attn.v_img.lora_up.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.22.cross_attn.k_img.diff_b
# [WARNING] lora key not loaded: diffusion_model.blocks.22.cross_attn.k_img.lora_down.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.22.cross_attn.k_img.lora_up.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.22.cross_attn.norm_k_img.diff
# [WARNING] lora key not loaded: diffusion_model.blocks.22.cross_attn.v_img.diff_b
# [WARNING] lora key not loaded: diffusion_model.blocks.22.cross_attn.v_img.lora_down.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.22.cross_attn.v_img.lora_up.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.23.cross_attn.k_img.diff_b
# [WARNING] lora key not loaded: diffusion_model.blocks.23.cross_attn.k_img.lora_down.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.23.cross_attn.k_img.lora_up.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.23.cross_attn.norm_k_img.diff
# [WARNING] lora key not loaded: diffusion_model.blocks.23.cross_attn.v_img.diff_b
# [WARNING] lora key not loaded: diffusion_model.blocks.23.cross_attn.v_img.lora_down.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.23.cross_attn.v_img.lora_up.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.24.cross_attn.k_img.diff_b
# [WARNING] lora key not loaded: diffusion_model.blocks.24.cross_attn.k_img.lora_down.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.24.cross_attn.k_img.lora_up.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.24.cross_attn.norm_k_img.diff
# [WARNING] lora key not loaded: diffusion_model.blocks.24.cross_attn.v_img.diff_b
# [WARNING] lora key not loaded: diffusion_model.blocks.24.cross_attn.v_img.lora_down.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.24.cross_attn.v_img.lora_up.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.25.cross_attn.k_img.diff_b
# [WARNING] lora key not loaded: diffusion_model.blocks.25.cross_attn.k_img.lora_down.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.25.cross_attn.k_img.lora_up.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.25.cross_attn.norm_k_img.diff
# [WARNING] lora key not loaded: diffusion_model.blocks.25.cross_attn.v_img.diff_b
# [WARNING] lora key not loaded: diffusion_model.blocks.25.cross_attn.v_img.lora_down.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.25.cross_attn.v_img.lora_up.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.26.cross_attn.k_img.diff_b
# [WARNING] lora key not loaded: diffusion_model.blocks.26.cross_attn.k_img.lora_down.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.26.cross_attn.k_img.lora_up.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.26.cross_attn.norm_k_img.diff
# [WARNING] lora key not loaded: diffusion_model.blocks.26.cross_attn.v_img.diff_b
# [WARNING] lora key not loaded: diffusion_model.blocks.26.cross_attn.v_img.lora_down.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.26.cross_attn.v_img.lora_up.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.27.cross_attn.k_img.diff_b
# [WARNING] lora key not loaded: diffusion_model.blocks.27.cross_attn.k_img.lora_down.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.27.cross_attn.k_img.lora_up.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.27.cross_attn.norm_k_img.diff
# [WARNING] lora key not loaded: diffusion_model.blocks.27.cross_attn.v_img.diff_b
# [WARNING] lora key not loaded: diffusion_model.blocks.27.cross_attn.v_img.lora_down.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.27.cross_attn.v_img.lora_up.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.28.cross_attn.k_img.diff_b
# [WARNING] lora key not loaded: diffusion_model.blocks.28.cross_attn.k_img.lora_down.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.28.cross_attn.k_img.lora_up.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.28.cross_attn.norm_k_img.diff
# [WARNING] lora key not loaded: diffusion_model.blocks.28.cross_attn.v_img.diff_b
# [WARNING] lora key not loaded: diffusion_model.blocks.28.cross_attn.v_img.lora_down.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.28.cross_attn.v_img.lora_up.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.29.cross_attn.k_img.diff_b
# [WARNING] lora key not loaded: diffusion_model.blocks.29.cross_attn.k_img.lora_down.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.29.cross_attn.k_img.lora_up.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.29.cross_attn.norm_k_img.diff
# [WARNING] lora key not loaded: diffusion_model.blocks.29.cross_attn.v_img.diff_b
# [WARNING] lora key not loaded: diffusion_model.blocks.29.cross_attn.v_img.lora_down.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.29.cross_attn.v_img.lora_up.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.3.cross_attn.k_img.diff_b
# [WARNING] lora key not loaded: diffusion_model.blocks.3.cross_attn.k_img.lora_down.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.3.cross_attn.k_img.lora_up.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.3.cross_attn.norm_k_img.diff
# [WARNING] lora key not loaded: diffusion_model.blocks.3.cross_attn.v_img.diff_b
# [WARNING] lora key not loaded: diffusion_model.blocks.3.cross_attn.v_img.lora_down.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.3.cross_attn.v_img.lora_up.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.30.cross_attn.k_img.diff_b
# [WARNING] lora key not loaded: diffusion_model.blocks.30.cross_attn.k_img.lora_down.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.30.cross_attn.k_img.lora_up.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.30.cross_attn.norm_k_img.diff
# [WARNING] lora key not loaded: diffusion_model.blocks.30.cross_attn.v_img.diff_b
# [WARNING] lora key not loaded: diffusion_model.blocks.30.cross_attn.v_img.lora_down.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.30.cross_attn.v_img.lora_up.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.31.cross_attn.k_img.diff_b
# [WARNING] lora key not loaded: diffusion_model.blocks.31.cross_attn.k_img.lora_down.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.31.cross_attn.k_img.lora_up.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.31.cross_attn.norm_k_img.diff
# [WARNING] lora key not loaded: diffusion_model.blocks.31.cross_attn.v_img.diff_b
# [WARNING] lora key not loaded: diffusion_model.blocks.31.cross_attn.v_img.lora_down.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.31.cross_attn.v_img.lora_up.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.32.cross_attn.k_img.diff_b
# [WARNING] lora key not loaded: diffusion_model.blocks.32.cross_attn.k_img.lora_down.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.32.cross_attn.k_img.lora_up.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.32.cross_attn.norm_k_img.diff
# [WARNING] lora key not loaded: diffusion_model.blocks.32.cross_attn.v_img.diff_b
# [WARNING] lora key not loaded: diffusion_model.blocks.32.cross_attn.v_img.lora_down.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.32.cross_attn.v_img.lora_up.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.33.cross_attn.k_img.diff_b
# [WARNING] lora key not loaded: diffusion_model.blocks.33.cross_attn.k_img.lora_down.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.33.cross_attn.k_img.lora_up.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.33.cross_attn.norm_k_img.diff
# [WARNING] lora key not loaded: diffusion_model.blocks.33.cross_attn.v_img.diff_b
# [WARNING] lora key not loaded: diffusion_model.blocks.33.cross_attn.v_img.lora_down.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.33.cross_attn.v_img.lora_up.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.34.cross_attn.k_img.diff_b
# [WARNING] lora key not loaded: diffusion_model.blocks.34.cross_attn.k_img.lora_down.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.34.cross_attn.k_img.lora_up.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.34.cross_attn.norm_k_img.diff
# [WARNING] lora key not loaded: diffusion_model.blocks.34.cross_attn.v_img.diff_b
# [WARNING] lora key not loaded: diffusion_model.blocks.34.cross_attn.v_img.lora_down.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.34.cross_attn.v_img.lora_up.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.35.cross_attn.k_img.diff_b
# [WARNING] lora key not loaded: diffusion_model.blocks.35.cross_attn.k_img.lora_down.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.35.cross_attn.k_img.lora_up.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.35.cross_attn.norm_k_img.diff
# [WARNING] lora key not loaded: diffusion_model.blocks.35.cross_attn.v_img.diff_b
# [WARNING] lora key not loaded: diffusion_model.blocks.35.cross_attn.v_img.lora_down.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.35.cross_attn.v_img.lora_up.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.36.cross_attn.k_img.diff_b
# [WARNING] lora key not loaded: diffusion_model.blocks.36.cross_attn.k_img.lora_down.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.36.cross_attn.k_img.lora_up.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.36.cross_attn.norm_k_img.diff
# [WARNING] lora key not loaded: diffusion_model.blocks.36.cross_attn.v_img.diff_b
# [WARNING] lora key not loaded: diffusion_model.blocks.36.cross_attn.v_img.lora_down.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.36.cross_attn.v_img.lora_up.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.37.cross_attn.k_img.diff_b
# [WARNING] lora key not loaded: diffusion_model.blocks.37.cross_attn.k_img.lora_down.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.37.cross_attn.k_img.lora_up.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.37.cross_attn.norm_k_img.diff
# [WARNING] lora key not loaded: diffusion_model.blocks.37.cross_attn.v_img.diff_b
# [WARNING] lora key not loaded: diffusion_model.blocks.37.cross_attn.v_img.lora_down.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.37.cross_attn.v_img.lora_up.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.38.cross_attn.k_img.diff_b
# [WARNING] lora key not loaded: diffusion_model.blocks.38.cross_attn.k_img.lora_down.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.38.cross_attn.k_img.lora_up.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.38.cross_attn.norm_k_img.diff
# [WARNING] lora key not loaded: diffusion_model.blocks.38.cross_attn.v_img.diff_b
# [WARNING] lora key not loaded: diffusion_model.blocks.38.cross_attn.v_img.lora_down.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.38.cross_attn.v_img.lora_up.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.39.cross_attn.k_img.diff_b
# [WARNING] lora key not loaded: diffusion_model.blocks.39.cross_attn.k_img.lora_down.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.39.cross_attn.k_img.lora_up.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.39.cross_attn.norm_k_img.diff
# [WARNING] lora key not loaded: diffusion_model.blocks.39.cross_attn.v_img.diff_b
# [WARNING] lora key not loaded: diffusion_model.blocks.39.cross_attn.v_img.lora_down.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.39.cross_attn.v_img.lora_up.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.4.cross_attn.k_img.diff_b
# [WARNING] lora key not loaded: diffusion_model.blocks.4.cross_attn.k_img.lora_down.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.4.cross_attn.k_img.lora_up.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.4.cross_attn.norm_k_img.diff
# [WARNING] lora key not loaded: diffusion_model.blocks.4.cross_attn.v_img.diff_b
# [WARNING] lora key not loaded: diffusion_model.blocks.4.cross_attn.v_img.lora_down.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.4.cross_attn.v_img.lora_up.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.5.cross_attn.k_img.diff_b
# [WARNING] lora key not loaded: diffusion_model.blocks.5.cross_attn.k_img.lora_down.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.5.cross_attn.k_img.lora_up.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.5.cross_attn.norm_k_img.diff
# [WARNING] lora key not loaded: diffusion_model.blocks.5.cross_attn.v_img.diff_b
# [WARNING] lora key not loaded: diffusion_model.blocks.5.cross_attn.v_img.lora_down.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.5.cross_attn.v_img.lora_up.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.6.cross_attn.k_img.diff_b
# [WARNING] lora key not loaded: diffusion_model.blocks.6.cross_attn.k_img.lora_down.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.6.cross_attn.k_img.lora_up.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.6.cross_attn.norm_k_img.diff
# [WARNING] lora key not loaded: diffusion_model.blocks.6.cross_attn.v_img.diff_b
# [WARNING] lora key not loaded: diffusion_model.blocks.6.cross_attn.v_img.lora_down.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.6.cross_attn.v_img.lora_up.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.7.cross_attn.k_img.diff_b
# [WARNING] lora key not loaded: diffusion_model.blocks.7.cross_attn.k_img.lora_down.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.7.cross_attn.k_img.lora_up.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.7.cross_attn.norm_k_img.diff
# [WARNING] lora key not loaded: diffusion_model.blocks.7.cross_attn.v_img.diff_b
# [WARNING] lora key not loaded: diffusion_model.blocks.7.cross_attn.v_img.lora_down.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.7.cross_attn.v_img.lora_up.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.8.cross_attn.k_img.diff_b
# [WARNING] lora key not loaded: diffusion_model.blocks.8.cross_attn.k_img.lora_down.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.8.cross_attn.k_img.lora_up.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.8.cross_attn.norm_k_img.diff
# [WARNING] lora key not loaded: diffusion_model.blocks.8.cross_attn.v_img.diff_b
# [WARNING] lora key not loaded: diffusion_model.blocks.8.cross_attn.v_img.lora_down.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.8.cross_attn.v_img.lora_up.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.9.cross_attn.k_img.diff_b
# [WARNING] lora key not loaded: diffusion_model.blocks.9.cross_attn.k_img.lora_down.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.9.cross_attn.k_img.lora_up.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.9.cross_attn.norm_k_img.diff
# [WARNING] lora key not loaded: diffusion_model.blocks.9.cross_attn.v_img.diff_b
# [WARNING] lora key not loaded: diffusion_model.blocks.9.cross_attn.v_img.lora_down.weight
# [WARNING] lora key not loaded: diffusion_model.blocks.9.cross_attn.v_img.lora_up.weight
# [WARNING] lora key not loaded: diffusion_model.img_emb.proj.0.diff
# [WARNING] lora key not loaded: diffusion_model.img_emb.proj.0.diff_b
# [WARNING] lora key not loaded: diffusion_model.img_emb.proj.1.diff_b
# [WARNING] lora key not loaded: diffusion_model.img_emb.proj.1.lora_down.weight
# [WARNING] lora key not loaded: diffusion_model.img_emb.proj.1.lora_up.weight
# [WARNING] lora key not loaded: diffusion_model.img_emb.proj.3.diff_b
# [WARNING] lora key not loaded: diffusion_model.img_emb.proj.3.lora_down.weight
# [WARNING] lora key not loaded: diffusion_model.img_emb.proj.3.lora_up.weight
# [WARNING] lora key not loaded: diffusion_model.img_emb.proj.4.diff
# [WARNING] lora key not loaded: diffusion_model.img_emb.proj.4.diff_b
# [INFO] Requested to load WanTEModel
# [INFO] Model WanTEModel prepared for dynamic VRAM loading. 6419MB Staged. 0 patches attached. Force pre-loaded 73 weights: 488 KB.
# FETCH ComfyRegistry Data: 35/164
# FETCH ComfyRegistry Data: 40/164
# FETCH ComfyRegistry Data: 45/164
# FETCH ComfyRegistry Data: 50/164
# FETCH ComfyRegistry Data: 55/164
# FETCH ComfyRegistry Data: 60/164
# FETCH ComfyRegistry Data: 65/164
# FETCH ComfyRegistry Data: 70/164
# [INFO] Requested to load WanTEModel
# [INFO] Model WanTEModel prepared for dynamic VRAM loading. 6419MB Staged. 0 patches attached. Force pre-loaded 73 weights: 488 KB.
# FETCH ComfyRegistry Data: 75/164
# FETCH ComfyRegistry Data: 80/164
# FETCH ComfyRegistry Data: 85/164
# FETCH ComfyRegistry Data: 90/164
# FETCH ComfyRegistry Data: 95/164
# FETCH ComfyRegistry Data: 100/164
# FETCH ComfyRegistry Data: 105/164
# FETCH ComfyRegistry Data: 110/164
# [INFO] Requested to load WanVAE
# [INFO] Model WanVAE prepared for dynamic VRAM loading. 241MB Staged. 0 patches attached. Force pre-loaded 60 weights: 61 KB.
# FETCH ComfyRegistry Data: 115/164
# FETCH ComfyRegistry Data: 120/164
# [INFO] Requested to load WAN21
# FETCH ComfyRegistry Data: 125/164
# [INFO] Model WAN21 prepared for dynamic VRAM loading. 13630MB Staged. 893 patches attached. Force pre-loaded 160 weights: 1603 KB.
# [INFO] Patching torch settings: torch.backends.cuda.matmul.allow_fp16_accumulation = True
#   0% 0/3 [00:00<?, ?it/s,   Model Initializing ...  ]FETCH ComfyRegistry Data: 130/164
# /usr/local/lib/python3.12/dist-packages/sageattention/attn_qk_int8_per_block.py:18:23: error: 'arith.extf' op operand #0 must be floating-point-like, but got 'tensor<128x128xi8, #ttg.dot_op<{opIdx = 0, parent = #ttg.blocked<{sizePerThread = [4, 4], threadsPerWarp = [2, 16], warpsPerCTA = [8, 1], order = [1, 0]}>}>>'
#         qk = tl.dot(q, k).to(tl.float32) * q_scale * k_scale
#                       ^
# /usr/local/lib/python3.12/dist-packages/sageattention/attn_qk_int8_per_block.py:78:55: note: called from
#                                     4 - STAGE, offs_m, offs_n
#                                                       ^
# module {
#   tt.func public @_attn_fwd(%arg0: !tt.ptr<i8> {tt.divisibility = 16 : i32}, %arg1: !tt.ptr<i8> {tt.divisibility = 16 : i32}, %arg2: !tt.ptr<f16> {tt.divisibility = 16 : i32}, %arg3: !tt.ptr<f32> {tt.divisibility = 16 : i32}, %arg4: !tt.ptr<f32> {tt.divisibility = 16 : i32}, %arg5: !tt.ptr<f16> {tt.divisibility = 16 : i32}, %arg6: i32 {tt.divisibility = 16 : i32}, %arg7: i32 {tt.divisibility = 16 : i32}, %arg8: i32 {tt.divisibility = 16 : i32}, %arg9: i32 {tt.divisibility = 16 : i32}, %arg10: i32 {tt.divisibility = 16 : i32}, %arg11: i32 {tt.divisibility = 16 : i32}, %arg12: i32 {tt.divisibility = 16 : i32}, %arg13: i32 {tt.divisibility = 16 : i32}, %arg14: i32 {tt.divisibility = 16 : i32}, %arg15: i32 {tt.divisibility = 16 : i32}, %arg16: i32 {tt.divisibility = 16 : i32}, %arg17: i32 {tt.divisibility = 16 : i32}, %arg18: i32, %arg19: i32) attributes {noinline = false} {
#     %cst = arith.constant dense<1.000000e+00> : tensor<128xf32>
#     %cst_0 = arith.constant dense<0xFF800000> : tensor<128xf32>
#     %c0_i32 = arith.constant 0 : i32
#     %cst_1 = arith.constant dense<0> : tensor<128x64xi32>
#     %cst_2 = arith.constant dense<0.000000e+00> : tensor<128x128xf16>
#     %c1_i32 = arith.constant 1 : i32
#     %cst_3 = arith.constant dense<0.000000e+00> : tensor<128x128xf32>
#     %c63_i32 = arith.constant 63 : i32
#     %c64_i32 = arith.constant 64 : i32
#     %c127_i32 = arith.constant 127 : i32
#     %c128_i32 = arith.constant 128 : i32
#     %c40_i64 = arith.constant 40 : i64
#     %0 = tt.get_program_id x : i32
#     %1 = tt.get_program_id z : i32
#     %2 = arith.extsi %1 : i32 to i64
#     %3 = tt.get_program_id y : i32
#     %4 = arith.extsi %3 : i32 to i64
#     %5 = arith.muli %2, %c40_i64 : i64
#     %6 = arith.addi %5, %4 : i64
#     %7 = arith.addi %arg18, %c127_i32 : i32
#     %8 = arith.divsi %7, %c128_i32 : i32
#     %9 = arith.extsi %8 : i32 to i64
#     %10 = arith.muli %6, %9 : i64
#     %11 = arith.addi %arg19, %c63_i32 : i32
#     %12 = arith.divsi %11, %c64_i32 : i32
#     %13 = arith.extsi %12 : i32 to i64
#     %14 = arith.muli %6, %13 : i64
#     %15 = arith.muli %0, %c128_i32 : i32
#     %16 = tt.make_range {end = 128 : i32, start = 0 : i32} : tensor<128xi32>
#     %17 = tt.splat %15 : i32 -> tensor<128xi32>
#     %18 = arith.addi %17, %16 : tensor<128xi32>
#     %19 = tt.make_range {end = 64 : i32, start = 0 : i32} : tensor<64xi32>
#     %20 = arith.extsi %arg6 : i32 to i64
#     %21 = arith.muli %2, %20 : i64
#     %22 = arith.extsi %arg7 : i32 to i64
#     %23 = arith.muli %4, %22 : i64
#     %24 = arith.addi %21, %23 : i64
#     %25 = tt.addptr %arg0, %24 : !tt.ptr<i8>, i64
#     %26 = tt.expand_dims %18 {axis = 1 : i32} : tensor<128xi32> -> tensor<128x1xi32>
#     %27 = tt.splat %arg8 : i32 -> tensor<128x1xi32>
#     %28 = arith.muli %26, %27 : tensor<128x1xi32>
#     %29 = tt.splat %25 : !tt.ptr<i8> -> tensor<128x1x!tt.ptr<i8>>
#     %30 = tt.addptr %29, %28 : tensor<128x1x!tt.ptr<i8>>, tensor<128x1xi32>
#     %31 = tt.expand_dims %16 {axis = 0 : i32} : tensor<128xi32> -> tensor<1x128xi32>
#     %32 = tt.broadcast %30 : tensor<128x1x!tt.ptr<i8>> -> tensor<128x128x!tt.ptr<i8>>
#     %33 = tt.broadcast %31 : tensor<1x128xi32> -> tensor<128x128xi32>
#     %34 = tt.addptr %32, %33 : tensor<128x128x!tt.ptr<i8>>, tensor<128x128xi32>
#     %35 = tt.addptr %arg3, %10 : !tt.ptr<f32>, i64
#     %36 = tt.addptr %35, %0 : !tt.ptr<f32>, i32
#     %37 = arith.extsi %arg9 : i32 to i64
#     %38 = arith.muli %2, %37 : i64
#     %39 = arith.extsi %arg10 : i32 to i64
#     %40 = arith.muli %4, %39 : i64
#     %41 = arith.addi %38, %40 : i64
#     %42 = tt.addptr %arg1, %41 : !tt.ptr<i8>, i64
#     %43 = tt.expand_dims %19 {axis = 0 : i32} : tensor<64xi32> -> tensor<1x64xi32>
#     %44 = tt.splat %arg11 : i32 -> tensor<1x64xi32>
#     %45 = arith.muli %43, %44 : tensor<1x64xi32>
#     %46 = tt.splat %42 : !tt.ptr<i8> -> tensor<1x64x!tt.ptr<i8>>
#     %47 = tt.addptr %46, %45 : tensor<1x64x!tt.ptr<i8>>, tensor<1x64xi32>
#     %48 = tt.expand_dims %16 {axis = 1 : i32} : tensor<128xi32> -> tensor<128x1xi32>
#     %49 = tt.broadcast %47 : tensor<1x64x!tt.ptr<i8>> -> tensor<128x64x!tt.ptr<i8>>
#     %50 = tt.broadcast %48 : tensor<128x1xi32> -> tensor<128x64xi32>
#     %51 = tt.addptr %49, %50 : tensor<128x64x!tt.ptr<i8>>, tensor<128x64xi32>
#     %52 = tt.addptr %arg4, %14 : !tt.ptr<f32>, i64
#     %53 = arith.extsi %arg12 : i32 to i64
#     %54 = arith.muli %2, %53 : i64
#     %55 = arith.extsi %arg13 : i32 to i64
#     %56 = arith.muli %4, %55 : i64
#     %57 = arith.addi %54, %56 : i64
#     %58 = tt.addptr %arg2, %57 : !tt.ptr<f16>, i64
#     %59 = tt.expand_dims %19 {axis = 1 : i32} : tensor<64xi32> -> tensor<64x1xi32>
#     %60 = tt.splat %arg14 : i32 -> tensor<64x1xi32>
#     %61 = arith.muli %59, %60 : tensor<64x1xi32>
#     %62 = tt.splat %58 : !tt.ptr<f16> -> tensor<64x1x!tt.ptr<f16>>
#     %63 = tt.addptr %62, %61 : tensor<64x1x!tt.ptr<f16>>, tensor<64x1xi32>
#     %64 = tt.broadcast %63 : tensor<64x1x!tt.ptr<f16>> -> tensor<64x128x!tt.ptr<f16>>
#     %65 = tt.broadcast %31 : tensor<1x128xi32> -> tensor<64x128xi32>
#     %66 = tt.addptr %64, %65 : tensor<64x128x!tt.ptr<f16>>, tensor<64x128xi32>
#     %67 = arith.extsi %arg15 : i32 to i64
#     %68 = arith.muli %2, %67 : i64
#     %69 = arith.extsi %arg16 : i32 to i64
#     %70 = arith.muli %4, %69 : i64
#     %71 = arith.addi %68, %70 : i64
#     %72 = tt.addptr %arg5, %71 : !tt.ptr<f16>, i64
#     %73 = tt.splat %arg17 : i32 -> tensor<128x1xi32>
#     %74 = arith.muli %26, %73 : tensor<128x1xi32>
#     %75 = tt.splat %72 : !tt.ptr<f16> -> tensor<128x1x!tt.ptr<f16>>
#     %76 = tt.addptr %75, %74 : tensor<128x1x!tt.ptr<f16>>, tensor<128x1xi32>
#     %77 = tt.broadcast %76 : tensor<128x1x!tt.ptr<f16>> -> tensor<128x128x!tt.ptr<f16>>
#     %78 = tt.addptr %77, %33 : tensor<128x128x!tt.ptr<f16>>, tensor<128x128xi32>
#     %79 = tt.splat %arg18 : i32 -> tensor<128x1xi32>
#     %80 = arith.cmpi slt, %26, %79 : tensor<128x1xi32>
#     %81 = tt.broadcast %80 : tensor<128x1xi1> -> tensor<128x128xi1>
#     %82 = tt.load %34, %81 : tensor<128x128x!tt.ptr<i8>>
#     %83 = tt.load %36 : !tt.ptr<f32>
#     %84:6 = scf.for %arg20 = %c0_i32 to %arg19 step %c64_i32 iter_args(%arg21 = %cst_3, %arg22 = %cst, %arg23 = %cst_0, %arg24 = %51, %arg25 = %52, %arg26 = %66) -> (tensor<128x128xf32>, tensor<128xf32>, tensor<128xf32>, tensor<128x64x!tt.ptr<i8>>, !tt.ptr<f32>, tensor<64x128x!tt.ptr<f16>>)  : i32 {
#       %89 = arith.subi %arg19, %arg20 : i32
#       %90 = tt.splat %89 : i32 -> tensor<1x64xi32>
#       %91 = arith.cmpi slt, %43, %90 : tensor<1x64xi32>
#       %92 = tt.broadcast %91 : tensor<1x64xi1> -> tensor<128x64xi1>
#       %93 = tt.load %arg24, %92 : tensor<128x64x!tt.ptr<i8>>
#       %94 = tt.load %arg25 : !tt.ptr<f32>
#       %95 = tt.dot %82, %93, %cst_1, inputPrecision = tf32 : tensor<128x128xi8> * tensor<128x64xi8> -> tensor<128x64xi32>
#       %96 = arith.sitofp %95 : tensor<128x64xi32> to tensor<128x64xf32>
#       %97 = tt.splat %83 : f32 -> tensor<128x64xf32>
#       %98 = arith.mulf %96, %97 : tensor<128x64xf32>
#       %99 = tt.splat %94 : f32 -> tensor<128x64xf32>
#       %100 = arith.mulf %98, %99 : tensor<128x64xf32>
#       %101 = "tt.reduce"(%100) <{axis = 1 : i32}> ({
#       ^bb0(%arg27: f32, %arg28: f32):
#         %130 = arith.maxnumf %arg27, %arg28 : f32
#         tt.reduce.return %130 : f32
#       }) : (tensor<128x64xf32>) -> tensor<128xf32>
#       %102 = arith.maxnumf %arg23, %101 : tensor<128xf32>
#       %103 = tt.expand_dims %102 {axis = 1 : i32} : tensor<128xf32> -> tensor<128x1xf32>
#       %104 = tt.broadcast %103 : tensor<128x1xf32> -> tensor<128x64xf32>
#       %105 = arith.subf %100, %104 : tensor<128x64xf32>
#       %106 = math.exp2 %105 : tensor<128x64xf32>
#       %107 = "tt.reduce"(%106) <{axis = 1 : i32}> ({
#       ^bb0(%arg27: f32, %arg28: f32):
#         %130 = arith.addf %arg27, %arg28 : f32
#         tt.reduce.return %130 : f32
#       }) : (tensor<128x64xf32>) -> tensor<128xf32>
#       %108 = arith.subf %arg23, %102 : tensor<128xf32>
#       %109 = math.exp2 %108 : tensor<128xf32>
#       %110 = arith.mulf %arg22, %109 : tensor<128xf32>
#       %111 = arith.addf %110, %107 : tensor<128xf32>
#       %112 = tt.expand_dims %109 {axis = 1 : i32} : tensor<128xf32> -> tensor<128x1xf32>
#       %113 = tt.broadcast %112 : tensor<128x1xf32> -> tensor<128x128xf32>
#       %114 = arith.mulf %arg21, %113 : tensor<128x128xf32>
#       %115 = tt.splat %89 : i32 -> tensor<64x1xi32>
#       %116 = arith.cmpi slt, %59, %115 : tensor<64x1xi32>
#       %117 = tt.broadcast %116 : tensor<64x1xi1> -> tensor<64x128xi1>
#       %118 = tt.load %arg26, %117 : tensor<64x128x!tt.ptr<f16>>
#       %119 = arith.truncf %106 : tensor<128x64xf32> to tensor<128x64xf16>
#       %120 = tt.dot %119, %118, %cst_2, inputPrecision = tf32 : tensor<128x64xf16> * tensor<64x128xf16> -> tensor<128x128xf16>
#       %121 = arith.extf %120 : tensor<128x128xf16> to tensor<128x128xf32>
#       %122 = arith.addf %114, %121 : tensor<128x128xf32>
#       %123 = arith.muli %arg11, %c64_i32 : i32
#       %124 = tt.splat %123 : i32 -> tensor<128x64xi32>
#       %125 = tt.addptr %arg24, %124 : tensor<128x64x!tt.ptr<i8>>, tensor<128x64xi32>
#       %126 = tt.addptr %arg25, %c1_i32 : !tt.ptr<f32>, i32
#       %127 = arith.muli %arg14, %c64_i32 : i32
#       %128 = tt.splat %127 : i32 -> tensor<64x128xi32>
#       %129 = tt.addptr %arg26, %128 : tensor<64x128x!tt.ptr<f16>>, tensor<64x128xi32>
#       scf.yield %122, %111, %102, %125, %126, %129 : tensor<128x128xf32>, tensor<128xf32>, tensor<128xf32>, tensor<128x64x!tt.ptr<i8>>, !tt.ptr<f32>, tensor<64x128x!tt.ptr<f16>>
#     }
#     %85 = tt.expand_dims %84#1 {axis = 1 : i32} : tensor<128xf32> -> tensor<128x1xf32>
#     %86 = tt.broadcast %85 : tensor<128x1xf32> -> tensor<128x128xf32>
#     %87 = arith.divf %84#0, %86 : tensor<128x128xf32>
#     %88 = arith.truncf %87 : tensor<128x128xf32> to tensor<128x128xf16>
#     tt.store %78, %88, %81 : tensor<128x128x!tt.ptr<f16>>
#     tt.return
#   }
# }
#
# {-#
#   external_resources: {
#     mlir_reproducer: {
# ...
# [INFO] Memory profile cache hit for cuda_1c57cab3-39b1-b767-1430-78ea5af94638::608::416::1216::832::3::fp32::linear: optimal_batch_size=3, max_safe_chunk=2048
# [INFO] Memory profile cache hit for cuda_1c57cab3-39b1-b767-1430-78ea5af94638::608::416::1216::832::3::fp32::linear: optimal_batch_size=3, max_safe_chunk=2048
# [INFO] Memory profile cache hit for cuda_1c57cab3-39b1-b767-1430-78ea5af94638::608::416::1216::832::3::fp32::linear: optimal_batch_size=3, max_safe_chunk=2048
# [INFO] Memory profile cache hit for cuda_1c57cab3-39b1-b767-1430-78ea5af94638::608::416::1216::832::3::fp32::linear: optimal_batch_size=3, max_safe_chunk=2048
# [INFO] Memory profile cache hit for cuda_1c57cab3-39b1-b767-1430-78ea5af94638::608::416::1216::832::3::fp32::linear: optimal_batch_size=3, max_safe_chunk=2048
# [INFO] Memory profile cache hit for cuda_1c57cab3-39b1-b767-1430-78ea5af94638::608::416::1216::832::3::fp32::linear: optimal_batch_size=3, max_safe_chunk=2048
# [INFO] Memory profile cache hit for cuda_1c57cab3-39b1-b767-1430-78ea5af94638::608::416::1216::832::3::fp32::linear: optimal_batch_size=3, max_safe_chunk=2048
# [INFO] Memory profile cache hit for cuda_1c57cab3-39b1-b767-1430-78ea5af94638::608::416::1216::832::3::fp32::linear: optimal_batch_size=3, max_safe_chunk=2048
# [INFO] Memory profile cache hit for cuda_1c57cab3-39b1-b767-1430-78ea5af94638::608::416::1216::832::3::fp32::linear: optimal_batch_size=3, max_safe_chunk=2048
# [INFO] Memory profile cache hit for cuda_1c57cab3-39b1-b767-1430-78ea5af94638::608::416::1216::832::3::fp32::linear: optimal_batch_size=3, max_safe_chunk=2048
# [INFO] Memory profile cache hit for cuda_1c57cab3-39b1-b767-1430-78ea5af94638::608::416::1216::832::3::fp32::linear: optimal_batch_size=3, max_safe_chunk=2048
# [INFO] Memory profile cache hit for cuda_1c57cab3-39b1-b767-1430-78ea5af94638::608::416::1216::832::3::fp32::linear: optimal_batch_size=3, max_safe_chunk=2048
# [INFO] Memory profile cache hit for cuda_1c57cab3-39b1-b767-1430-78ea5af94638::608::416::1216::832::3::fp32::linear: optimal_batch_size=3, max_safe_chunk=2048
# [INFO] Memory profile cache hit for cuda_1c57cab3-39b1-b767-1430-78ea5af94638::608::416::1216::832::3::fp32::linear: optimal_batch_size=3, max_safe_chunk=2048
# [INFO] Memory profile cache hit for cuda_1c57cab3-39b1-b767-1430-78ea5af94638::608::416::1216::832::3::fp32::linear: optimal_batch_size=3, max_safe_chunk=2048
# [INFO] Memory profile cache hit for cuda_1c57cab3-39b1-b767-1430-78ea5af94638::608::416::1216::832::3::fp32::linear: optimal_batch_size=3, max_safe_chunk=2048
# [INFO] Memory profile cache hit for cuda_1c57cab3-39b1-b767-1430-78ea5af94638::608::416::1216::832::3::fp32::linear: optimal_batch_size=3, max_safe_chunk=2048
# [INFO] Memory profile cache hit for cuda_1c57cab3-39b1-b767-1430-78ea5af94638::608::416::1216::832::3::fp32::linear: optimal_batch_size=3, max_safe_chunk=2048
# [INFO] Memory profile cache hit for cuda_1c57cab3-39b1-b767-1430-78ea5af94638::608::416::1216::832::3::fp32::linear: optimal_batch_size=3, max_safe_chunk=2048
# [INFO] Memory profile cache hit for cuda_1c57cab3-39b1-b767-1430-78ea5af94638::608::416::1216::832::3::fp32::linear: optimal_batch_size=3, max_safe_chunk=2048
# [INFO] Memory profile cache hit for cuda_1c57cab3-39b1-b767-1430-78ea5af94638::608::416::1216::832::3::fp32::linear: optimal_batch_size=3, max_safe_chunk=2048
# [INFO] Memory profile cache hit for cuda_1c57cab3-39b1-b767-1430-78ea5af94638::608::416::1216::832::3::fp32::linear: optimal_batch_size=3, max_safe_chunk=2048
# [INFO] Memory profile cache hit for cuda_1c57cab3-39b1-b767-1430-78ea5af94638::608::416::1216::832::3::fp32::linear: optimal_batch_size=3, max_safe_chunk=2048
# [INFO] Memory profile cache hit for cuda_1c57cab3-39b1-b767-1430-78ea5af94638::608::416::1216::832::3::fp32::linear: optimal_batch_size=3, max_safe_chunk=2048
# [INFO] Memory profile cache hit for cuda_1c57cab3-39b1-b767-1430-78ea5af94638::608::416::1216::832::3::fp32::linear: optimal_batch_size=3, max_safe_chunk=2048
# [INFO] Memory profile cache hit for cuda_1c57cab3-39b1-b767-1430-78ea5af94638::608::416::1216::832::3::fp32::linear: optimal_batch_size=3, max_safe_chunk=2048
# [INFO] Memory profile cache hit for cuda_1c57cab3-39b1-b767-1430-78ea5af94638::608::416::1216::832::3::fp32::linear: optimal_batch_size=3, max_safe_chunk=2048
# [INFO] Memory profile cache hit for cuda_1c57cab3-39b1-b767-1430-78ea5af94638::608::416::1216::832::3::fp32::linear: optimal_batch_size=3, max_safe_chunk=2048
# [INFO] Memory profile cache hit for cuda_1c57cab3-39b1-b767-1430-78ea5af94638::608::416::1216::832::3::fp32::linear: optimal_batch_size=3, max_safe_chunk=2048
# [INFO] Memory profile cache hit for cuda_1c57cab3-39b1-b767-1430-78ea5af94638::608::416::1216::832::3::fp32::linear: optimal_batch_size=3, max_safe_chunk=2048
# [INFO] Memory profile cache hit for cuda_1c57cab3-39b1-b767-1430-78ea5af94638::608::416::1216::832::3::fp32::linear: optimal_batch_size=3, max_safe_chunk=2048
# [INFO] Memory profile cache hit for cuda_1c57cab3-39b1-b767-1430-78ea5af94638::608::416::1216::832::3::fp32::linear: optimal_batch_size=3, max_safe_chunk=2048
# [INFO] Memory profile cache hit for cuda_1c57cab3-39b1-b767-1430-78ea5af94638::608::416::1216::832::3::fp32::linear: optimal_batch_size=3, max_safe_chunk=2048
# [INFO] Memory profile cache hit for cuda_1c57cab3-39b1-b767-1430-78ea5af94638::608::416::1216::832::3::fp32::linear: optimal_batch_size=3, max_safe_chunk=2048
# [INFO] Prompt executed in 00:10:38
# [INFO] got prompt
# [INFO] Requested to load WanTEModel
# [INFO] Model WanTEModel prepared for dynamic VRAM loading. 6419MB Staged. 0 patches attached. Force pre-loaded 73 weights: 488 KB.
# [INFO] Requested to load WanVAE
# [INFO] Model WanVAE prepared for dynamic VRAM loading. 241MB Staged. 0 patches attached. Force pre-loaded 60 weights: 61 KB.
# [INFO] Requested to load WAN21
# [INFO] Model WAN21 prepared for dynamic VRAM loading. 13630MB Staged. 893 patches attached. Force pre-loaded 160 weights: 1603 KB.
# [INFO] Patching torch settings: torch.backends.cuda.matmul.allow_fp16_accumulation = True
# 100% 3/3 [02:49<00:00, 56.53s/it]
# [INFO] Patching torch settings: torch.backends.cuda.matmul.allow_fp16_accumulation = False
# [INFO] Requested to load WAN21
# [INFO] Model WAN21 prepared for dynamic VRAM loading. 13630MB Staged. 893 patches attached. Force pre-loaded 160 weights: 1603 KB.
# [INFO] Patching torch settings: torch.backends.cuda.matmul.allow_fp16_accumulation = True
# 100% 3/3 [02:54<00:00, 58.24s/it]
# [INFO] Patching torch settings: torch.backends.cuda.matmul.allow_fp16_accumulation = False
# [INFO] Requested to load WanVAE
# [INFO] Model WanVAE prepared for dynamic VRAM loading. 241MB Staged. 0 patches attached. Force pre-loaded 60 weights: 61 KB.
# Comfy-VFI: Using cached model rife49.pth (float32)
# Comfy-VFI: Clearing cache... Done cache clearing
# Comfy-VFI: Clearing cache... Done cache clearing
# Comfy-VFI: Clearing cache... Done cache clearing
# Comfy-VFI: Clearing cache... Done cache clearing
# Comfy-VFI: Clearing cache... Done cache clearing
# Comfy-VFI: Clearing cache... Done cache clearing
# Comfy-VFI: Clearing cache... Done cache clearing
# Comfy-VFI: Clearing cache... Done cache clearing
# Comfy-VFI: Final clearing cache... Done cache clearing
# Comfy-VFI done! 161 frames generated
# [INFO] Memory profile cache hit for cuda_1c57cab3-39b1-b767-1430-78ea5af94638::608::416::1216::832::3::fp32::linear: optimal_batch_size=3, max_safe_chunk=2048
# [INFO] Memory profile cache hit for cuda_1c57cab3-39b1-b767-1430-78ea5af94638::608::416::1216::832::3::fp32::linear: optimal_batch_size=3, max_safe_chunk=2048
# [INFO] Memory profile cache hit for cuda_1c57cab3-39b1-b767-1430-78ea5af94638::608::416::1216::832::3::fp32::linear: optimal_batch_size=3, max_safe_chunk=2048
# [INFO] Memory profile cache hit for cuda_1c57cab3-39b1-b767-1430-78ea5af94638::608::416::1216::832::3::fp32::linear: optimal_batch_size=3, max_safe_chunk=2048
# [INFO] Memory profile cache hit for cuda_1c57cab3-39b1-b767-1430-78ea5af94638::608::416::1216::832::3::fp32::linear: optimal_batch_size=3, max_safe_chunk=2048
# [INFO] Memory profile cache hit for cuda_1c57cab3-39b1-b767-1430-78ea5af94638::608::416::1216::832::3::fp32::linear: optimal_batch_size=3, max_safe_chunk=2048
# [INFO] Memory profile cache hit for cuda_1c57cab3-39b1-b767-1430-78ea5af94638::608::416::1216::832::3::fp32::linear: optimal_batch_size=3, max_safe_chunk=2048
# [INFO] Memory profile cache hit for cuda_1c57cab3-39b1-b767-1430-78ea5af94638::608::416::1216::832::3::fp32::linear: optimal_batch_size=3, max_safe_chunk=2048
# [INFO] Memory profile cache hit for cuda_1c57cab3-39b1-b767-1430-78ea5af94638::608::416::1216::832::3::fp32::linear: optimal_batch_size=3, max_safe_chunk=2048
# [INFO] Memory profile cache hit for cuda_1c57cab3-39b1-b767-1430-78ea5af94638::608::416::1216::832::3::fp32::linear: optimal_batch_size=3, max_safe_chunk=2048
# [INFO] Memory profile cache hit for cuda_1c57cab3-39b1-b767-1430-78ea5af94638::608::416::1216::832::3::fp32::linear: optimal_batch_size=3, max_safe_chunk=2048
# [INFO] Memory profile cache hit for cuda_1c57cab3-39b1-b767-1430-78ea5af94638::608::416::1216::832::3::fp32::linear: optimal_batch_size=3, max_safe_chunk=2048
# [INFO] Memory profile cache hit for cuda_1c57cab3-39b1-b767-1430-78ea5af94638::608::416::1216::832::3::fp32::linear: optimal_batch_size=3, max_safe_chunk=2048
# [INFO] Memory profile cache hit for cuda_1c57cab3-39b1-b767-1430-78ea5af94638::608::416::1216::832::3::fp32::linear: optimal_batch_size=3, max_safe_chunk=2048
# [INFO] Memory profile cache hit for cuda_1c57cab3-39b1-b767-1430-78ea5af94638::608::416::1216::832::3::fp32::linear: optimal_batch_size=3, max_safe_chunk=2048
# [INFO] Memory profile cache hit for cuda_1c57cab3-39b1-b767-1430-78ea5af94638::608::416::1216::832::3::fp32::linear: optimal_batch_size=3, max_safe_chunk=2048
# [INFO] Memory profile cache hit for cuda_1c57cab3-39b1-b767-1430-78ea5af94638::608::416::1216::832::3::fp32::linear: optimal_batch_size=3, max_safe_chunk=2048
# [INFO] Memory profile cache hit for cuda_1c57cab3-39b1-b767-1430-78ea5af94638::608::416::1216::832::3::fp32::linear: optimal_batch_size=3, max_safe_chunk=2048
# [INFO] Memory profile cache hit for cuda_1c57cab3-39b1-b767-1430-78ea5af94638::608::416::1216::832::3::fp32::linear: optimal_batch_size=3, max_safe_chunk=2048
# [INFO] Memory profile cache hit for cuda_1c57cab3-39b1-b767-1430-78ea5af94638::608::416::1216::832::3::fp32::linear: optimal_batch_size=3, max_safe_chunk=2048
# [INFO] Memory profile cache hit for cuda_1c57cab3-39b1-b767-1430-78ea5af94638::608::416::1216::832::3::fp32::linear: optimal_batch_size=3, max_safe_chunk=2048
# [INFO] Memory profile cache hit for cuda_1c57cab3-39b1-b767-1430-78ea5af94638::608::416::1216::832::3::fp32::linear: optimal_batch_size=3, max_safe_chunk=2048
# [INFO] Memory profile cache hit for cuda_1c57cab3-39b1-b767-1430-78ea5af94638::608::416::1216::832::3::fp32::linear: optimal_batch_size=3, max_safe_chunk=2048
# [INFO] Memory profile cache hit for cuda_1c57cab3-39b1-b767-1430-78ea5af94638::608::416::1216::832::3::fp32::linear: optimal_batch_size=3, max_safe_chunk=2048
# [INFO] Memory profile cache hit for cuda_1c57cab3-39b1-b767-1430-78ea5af94638::608::416::1216::832::3::fp32::linear: optimal_batch_size=3, max_safe_chunk=2048
# [INFO] Memory profile cache hit for cuda_1c57cab3-39b1-b767-1430-78ea5af94638::608::416::1216::832::3::fp32::linear: optimal_batch_size=3, max_safe_chunk=2048
# [INFO] Memory profile cache hit for cuda_1c57cab3-39b1-b767-1430-78ea5af94638::608::416::1216::832::3::fp32::linear: optimal_batch_size=3, max_safe_chunk=2048
# [INFO] Memory profile cache hit for cuda_1c57cab3-39b1-b767-1430-78ea5af94638::608::416::1216::832::3::fp32::linear: optimal_batch_size=3, max_safe_chunk=2048
# [INFO] Memory profile cache hit for cuda_1c57cab3-39b1-b767-1430-78ea5af94638::608::416::1216::832::3::fp32::linear: optimal_batch_size=3, max_safe_chunk=2048
# [INFO] Memory profile cache hit for cuda_1c57cab3-39b1-b767-1430-78ea5af94638::608::416::1216::832::3::fp32::linear: optimal_batch_size=3, max_safe_chunk=2048
# [INFO] Memory profile cache hit for cuda_1c57cab3-39b1-b767-1430-78ea5af94638::608::416::1216::832::3::fp32::linear: optimal_batch_size=3, max_safe_chunk=2048
# [INFO] Memory profile cache hit for cuda_1c57cab3-39b1-b767-1430-78ea5af94638::608::416::1216::832::3::fp32::linear: optimal_batch_size=3, max_safe_chunk=2048
# [INFO] Memory profile cache hit for cuda_1c57cab3-39b1-b767-1430-78ea5af94638::608::416::1216::832::3::fp32::linear: optimal_batch_size=3, max_safe_chunk=2048
# [INFO] Memory profile cache hit for cuda_1c57cab3-39b1-b767-1430-78ea5af94638::608::416::1216::832::3::fp32::linear: optimal_batch_size=3, max_safe_chunk=2048
# [INFO] Memory profile cache hit for cuda_1c57cab3-39b1-b767-1430-78ea5af94638::608::416::1216::832::3::fp32::linear: optimal_batch_size=3, max_safe_chunk=2048
# [INFO] Memory profile cache hit for cuda_1c57cab3-39b1-b767-1430-78ea5af94638::608::416::1216::832::3::fp32::linear: optimal_batch_size=3, max_safe_chunk=2048
# [INFO] Memory profile cache hit for cuda_1c57cab3-39b1-b767-1430-78ea5af94638::608::416::1216::832::3::fp32::linear: optimal_batch_size=3, max_safe_chunk=2048
# [INFO] Memory profile cache hit for cuda_1c57cab3-39b1-b767-1430-78ea5af94638::608::416::1216::832::3::fp32::linear: optimal_batch_size=3, max_safe_chunk=2048
# [INFO] Memory profile cache hit for cuda_1c57cab3-39b1-b767-1430-78ea5af94638::608::416::1216::832::3::fp32::linear: optimal_batch_size=3, max_safe_chunk=2048
# [INFO] Memory profile cache hit for cuda_1c57cab3-39b1-b767-1430-78ea5af94638::608::416::1216::832::3::fp32::linear: optimal_batch_size=3, max_safe_chunk=2048
# [INFO] Memory profile cache hit for cuda_1c57cab3-39b1-b767-1430-78ea5af94638::608::416::1216::832::3::fp32::linear: optimal_batch_size=3, max_safe_chunk=2048
# [INFO] Memory profile cache hit for cuda_1c57cab3-39b1-b767-1430-78ea5af94638::608::416::1216::832::3::fp32::linear: optimal_batch_size=3, max_safe_chunk=2048
# [INFO] Memory profile cache hit for cuda_1c57cab3-39b1-b767-1430-78ea5af94638::608::416::1216::832::3::fp32::linear: optimal_batch_size=3, max_safe_chunk=2048
# [INFO] Memory profile cache hit for cuda_1c57cab3-39b1-b767-1430-78ea5af94638::608::416::1216::832::3::fp32::linear: optimal_batch_size=3, max_safe_chunk=2048
# [INFO] Memory profile cache hit for cuda_1c57cab3-39b1-b767-1430-78ea5af94638::608::416::1216::832::3::fp32::linear: optimal_batch_size=3, max_safe_chunk=2048
# [INFO] Memory profile cache hit for cuda_1c57cab3-39b1-b767-1430-78ea5af94638::608::416::1216::832::3::fp32::linear: optimal_batch_size=3, max_safe_chunk=2048
# [INFO] Memory profile cache hit for cuda_1c57cab3-39b1-b767-1430-78ea5af94638::608::416::1216::832::3::fp32::linear: optimal_batch_size=3, max_safe_chunk=2048
# [INFO] Memory profile cache hit for cuda_1c57cab3-39b1-b767-1430-78ea5af94638::608::416::1216::832::3::fp32::linear: optimal_batch_size=3, max_safe_chunk=2048
# [INFO] Memory profile cache hit for cuda_1c57cab3-39b1-b767-1430-78ea5af94638::608::416::1216::832::3::fp32::linear: optimal_batch_size=3, max_safe_chunk=2048
# [INFO] Memory profile cache hit for cuda_1c57cab3-39b1-b767-1430-78ea5af94638::608::416::1216::832::3::fp32::linear: optimal_batch_size=3, max_safe_chunk=2048
# [INFO] Memory profile cache hit for cuda_1c57cab3-39b1-b767-1430-78ea5af94638::608::416::1216::832::3::fp32::linear: optimal_batch_size=3, max_safe_chunk=2048
# [INFO] Memory profile cache hit for cuda_1c57cab3-39b1-b767-1430-78ea5af94638::608::416::1216::832::3::fp32::linear: optimal_batch_size=3, max_safe_chunk=2048
# [INFO] Memory profile cache hit for cuda_1c57cab3-39b1-b767-1430-78ea5af94638::608::416::1216::832::3::fp32::linear: optimal_batch_size=3, max_safe_chunk=2048
# [INFO] Memory profile cache hit for cuda_1c57cab3-39b1-b767-1430-78ea5af94638::608::416::1216::832::3::fp32::linear: optimal_batch_size=3, max_safe_chunk=2048
# [INFO] Prompt executed in 00:10:16

# %%
# %cd /content/
# !wget https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64 -O cloudflared
# !chmod +x cloudflared
# !ls -l cloudflared
# !chmod +x cloudflared
# !./cloudflared --version
# !nohup ./cloudflared tunnel --url http://127.0.0.1:8188 --no-autoupdate > /content/cloudflared.log 2>&1 &
# Out:
# /content
# --2026-07-23 18:53:06--  https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64
# Resolving github.com (github.com)... 140.82.113.3
# Connecting to github.com (github.com)|140.82.113.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/cloudflare/cloudflared/releases/download/2026.7.3/cloudflared-linux-amd64 [following]
# --2026-07-23 18:53:06--  https://github.com/cloudflare/cloudflared/releases/download/2026.7.3/cloudflared-linux-amd64
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://release-assets.githubusercontent.com/github-production-release-asset/106867604/3812f7fa-ce13-4147-a9fb-197be83d49fa?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-07-23T19%3A40%3A08Z&rscd=attachment%3B+filename%3Dcloudflared-linux-amd64&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-07-23T18%3A39%3A32Z&ske=2026-07-23T19%3A40%3A08Z&sks=b&skv=2018-11-09&sig=R9609PkGrQDysRutpD9iuvtL9WbF0QJMIPZlSzR5jLY%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc4NDgzNDU4MywibmJmIjoxNzg0ODMyNzgzLCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.4UPyCLN2TZ4-k-Xl8AFFU1v--BqkMgsgC1Viue1IRIc&response-content-disposition=attachment%3B%20filename%3Dcloudflared-linux-amd64&response-content-type=application%2Foctet-stream [following]
# --2026-07-23 18:53:06--  https://release-assets.githubusercontent.com/github-production-release-asset/106867604/3812f7fa-ce13-4147-a9fb-197be83d49fa?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-07-23T19%3A40%3A08Z&rscd=attachment%3B+filename%3Dcloudflared-linux-amd64&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-07-23T18%3A39%3A32Z&ske=2026-07-23T19%3A40%3A08Z&sks=b&skv=2018-11-09&sig=R9609PkGrQDysRutpD9iuvtL9WbF0QJMIPZlSzR5jLY%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc4NDgzNDU4MywibmJmIjoxNzg0ODMyNzgzLCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.4UPyCLN2TZ4-k-Xl8AFFU1v--BqkMgsgC1Viue1IRIc&response-content-disposition=attachment%3B%20filename%3Dcloudflared-linux-amd64&response-content-type=application%2Foctet-stream
# Resolving release-assets.githubusercontent.com (release-assets.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to release-assets.githubusercontent.com (release-assets.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 39278667 (37M) [application/octet-stream]
# Saving to: ‘cloudflared’
#
# cloudflared         100%[===================>]  37.46M   169MB/s    in 0.2s
#
# 2026-07-23 18:53:06 (169 MB/s) - ‘cloudflared’ saved [39278667/39278667]
#
# -rwxr-xr-x 1 root root 39278667 Jul 23 10:19 cloudflared
# cloudflared version 2026.7.3 (built 2026-07-23-09:58 UTC)

# %%
# !grep -o 'https://[^ ]*trycloudflare.com' cloudflared.log
# Out:
# https://thomson-preferred-dividend-like.trycloudflare.com
