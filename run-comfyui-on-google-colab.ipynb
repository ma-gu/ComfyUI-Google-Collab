# %% [markdown]
# <a href="https://colab.research.google.com/github/ma-gu/ComfyUI-Google-Collab/blob/main/run-comfyui-on-google-colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Running ComfyUI in Google Colab
#
# To run ComfyUI in Google Colab, you need to enable GPU acceleration. Go to "Runtime" -> "Change runtime type" and select "GPU" as the hardware accelerator.

# %%
# Update package lists and install necessary packages
# !apt-get update
# !apt-get install -y wget aria2 libgl1-mesa-glx
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:2 https://cli.github.com/packages stable InRelease [3,917 B]
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:4 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ Packages [101 kB]
# Get:5 https://cli.github.com/packages stable/main amd64 Packages [355 B]
# Get:6 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [2,845 kB]
# Get:8 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:9 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:10 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [10.6 MB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:12 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Hit:13 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:14 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:15 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:16 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [3,125 kB]
# Get:17 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 Packages [43.4 kB]
# Get:18 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,313 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [4,462 kB]
# Get:20 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [4,120 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,616 kB]
# Get:22 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [7,683 kB]
# Get:23 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [7,381 kB]
# Get:24 http://archive.ubuntu.com/ubuntu jammy-backports/universe amd64 Packages [35.6 kB]
# Get:25 http://archive.ubuntu.com/ubuntu jammy-backports/main amd64 Packages [82.8 kB]
# Fetched 43.8 MB in 4s (12.0 MB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# libgl1-mesa-glx is already the newest version (23.0.4-0ubuntu1~22.04.1).
# The following additional packages will be installed:
#   libaria2-0 libc-ares2
# The following NEW packages will be installed:
#   aria2 libaria2-0 libc-ares2
# The following packages will be upgraded:
#   wget
# 1 upgraded, 3 newly installed, 0 to remove and 148 not upgraded.
# Need to get 1,852 kB of archives.
# After this operation, 5,441 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 wget amd64 1.21.2-2ubuntu1.4 [339 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libc-ares2 amd64 1.18.1-1ubuntu0.22.04.3 [45.1 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libaria2-0 amd64 1.36.0-1 [1,086 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/universe amd64 aria2 amd64 1.36.0-1 [381 kB]
# Fetched 1,852 kB in 1s (1,303 kB/s)
# (Reading database ... 122403 files and directories currently installed.)
# Preparing to unpack .../wget_1.21.2-2ubuntu1.4_amd64.deb ...
# Unpacking wget (1.21.2-2ubuntu1.4) over (1.21.2-2ubuntu1.1) ...
# Selecting previously unselected package libc-ares2:amd64.
# Preparing to unpack .../libc-ares2_1.18.1-1ubuntu0.22.04.3_amd64.deb ...
# Unpacking libc-ares2:amd64 (1.18.1-1ubuntu0.22.04.3) ...
# Selecting previously unselected package libaria2-0:amd64.
# Preparing to unpack .../libaria2-0_1.36.0-1_amd64.deb ...
# Unpacking libaria2-0:amd64 (1.36.0-1) ...
# Selecting previously unselected package aria2.
# Preparing to unpack .../aria2_1.36.0-1_amd64.deb ...
# Unpacking aria2 (1.36.0-1) ...
# Setting up wget (1.21.2-2ubuntu1.4) ...
# Setting up libc-ares2:amd64 (1.18.1-1ubuntu0.22.04.3) ...
# Setting up libaria2-0:amd64 (1.36.0-1) ...
# Setting up aria2 (1.36.0-1) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero_v2.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link

# %%
# Clone the ComfyUI repository from GitHub
# !git clone https://github.com/comfyanonymous/ComfyUI.git
# Out:
# Cloning into 'ComfyUI'...
# remote: Enumerating objects: 43398, done.
# remote: Counting objects: 100% (72/72), done.
# remote: Compressing objects: 100% (48/48), done.
# remote: Total 43398 (delta 47), reused 25 (delta 24), pack-reused 43326 (from 3)
# Receiving objects: 100% (43398/43398), 90.18 MiB | 19.25 MiB/s, done.
# Resolving deltas: 100% (29416/29416), done.

# %%
# Change the current directory to ComfyUI and install required Python packages
# %cd ComfyUI
# !pip install -r requirements.txt
# Out:
# /content/ComfyUI
# Collecting comfyui-frontend-package==1.45.21 (from -r requirements.txt (line 1))
#   Downloading comfyui_frontend_package-1.45.21-py3-none-any.whl.metadata (118 bytes)
# Collecting comfyui-workflow-templates==0.11.12 (from -r requirements.txt (line 2))
#   Downloading comfyui_workflow_templates-0.11.12-py3-none-any.whl.metadata (24 kB)
# Collecting comfyui-embedded-docs==0.5.8 (from -r requirements.txt (line 3))
#   Downloading comfyui_embedded_docs-0.5.8-py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 4)) (2.11.0+cu128)
# Collecting torchsde (from -r requirements.txt (line 5))
#   Downloading torchsde-0.2.6-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 6)) (0.26.0+cu128)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 7)) (2.11.0+cu128)
# Requirement already satisfied: numpy>=1.25.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 8)) (2.0.2)
# Requirement already satisfied: einops in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 9)) (0.8.2)
# Requirement already satisfied: transformers>=4.50.3 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 10)) (5.13.1)
# Requirement already satisfied: tokenizers>=0.13.3 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 11)) (0.22.2)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 12)) (0.2.2)
# Requirement already satisfied: safetensors>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 13)) (0.8.0)
# Requirement already satisfied: aiohttp>=3.11.8 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 14)) (3.14.1)
# Requirement already satisfied: yarl>=1.18.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 15)) (1.24.2)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 16)) (6.0.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 17)) (11.3.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 18)) (1.16.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 19)) (4.67.3)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 20)) (5.9.5)
# Collecting alembic (from -r requirements.txt (line 21))
#   Downloading alembic-1.18.5-py3-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: SQLAlchemy>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 22)) (2.0.51)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 23)) (3.29.7)
# Collecting av>=16.0.0 (from -r requirements.txt (line 24))
#   Downloading av-18.0.0-cp311-abi3-manylinux_2_28_x86_64.whl.metadata (4.5 kB)
# Collecting comfy-kitchen==0.2.22 (from -r requirements.txt (line 25))
#   Downloading comfy_kitchen-0.2.22-cp312-abi3-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (7.5 kB)
# Collecting comfy-aimdo==0.4.10 (from -r requirements.txt (line 26))
#   Downloading comfy_aimdo-0.4.10-cp39-abi3-manylinux2010_x86_64.manylinux2014_x86_64.manylinux_2_12_x86_64.manylinux_2_17_x86_64.whl.metadata (4.2 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 27)) (2.32.4)
# Collecting simpleeval>=1.0.0 (from -r requirements.txt (line 28))
#   Downloading simpleeval-1.0.7-py3-none-any.whl.metadata (20 kB)
# Collecting blake3 (from -r requirements.txt (line 29))
#   Downloading blake3-1.0.9-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting kornia>=0.7.1 (from -r requirements.txt (line 32))
#   Downloading kornia-0.8.3-py3-none-any.whl.metadata (22 kB)
# Collecting spandrel (from -r requirements.txt (line 33))
#   Downloading spandrel-0.4.2-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: pydantic~=2.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 34)) (2.13.4)
# Collecting pydantic-settings~=2.0 (from -r requirements.txt (line 35))
#   Downloading pydantic_settings-2.14.2-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: PyOpenGL>=3.1.8 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 36)) (3.1.10)
# Collecting comfy-angle (from -r requirements.txt (line 37))
#   Downloading comfy_angle-0.1.0-py3-none-manylinux_2_28_x86_64.whl.metadata (1.6 kB)
# Collecting comfyui-workflow-templates-core==0.3.275 (from comfyui-workflow-templates==0.11.12->-r requirements.txt (line 2))
#   Downloading comfyui_workflow_templates_core-0.3.275-py3-none-any.whl.metadata (260 bytes)
# Collecting comfyui-workflow-templates-json==0.1.9 (from comfyui-workflow-templates==0.11.12->-r requirements.txt (line 2))
#   Downloading comfyui_workflow_templates_json-0.1.9-py3-none-any.whl.metadata (264 bytes)
# Collecting comfyui-workflow-templates-media-api==0.3.84 (from comfyui-workflow-templates==0.11.12->-r requirements.txt (line 2))
#   Downloading comfyui_workflow_templates_media_api-0.3.84-py3-none-any.whl.metadata (290 bytes)
# Collecting comfyui-workflow-templates-media-video==0.3.101 (from comfyui-workflow-templates==0.11.12->-r requirements.txt (line 2))
#   Downloading comfyui_workflow_templates_media_video-0.3.101-py3-none-any.whl.metadata (283 bytes)
# Collecting comfyui-workflow-templates-media-image==0.3.160 (from comfyui-workflow-templates==0.11.12->-r requirements.txt (line 2))
#   Downloading comfyui_workflow_templates_media_image-0.3.160-py3-none-any.whl.metadata (283 bytes)
# Collecting comfyui-workflow-templates-media-other==0.3.229 (from comfyui-workflow-templates==0.11.12->-r requirements.txt (line 2))
#   Downloading comfyui_workflow_templates_media_other-0.3.229-py3-none-any.whl.metadata (306 bytes)
# Collecting comfyui-workflow-templates-media-assets-01==0.1.5 (from comfyui-workflow-templates==0.11.12->-r requirements.txt (line 2))
#   Downloading comfyui_workflow_templates_media_assets_01-0.1.5-py3-none-any.whl.metadata (289 bytes)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 4)) (4.16.0)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 4)) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 4)) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 4)) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 4)) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 4)) (2025.3.0)
# Requirement already satisfied: cuda-toolkit==12.8.1 in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r requirements.txt (line 4)) (12.8.1)
# Requirement already satisfied: cuda-bindings<13,>=12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 4)) (12.9.7)
# Requirement already satisfied: nvidia-cudnn-cu12==9.19.0.56 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 4)) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 4)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.28.9 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 4)) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 4)) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 4)) (3.6.0)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r requirements.txt (line 4)) (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r requirements.txt (line 4)) (12.8.90)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r requirements.txt (line 4)) (11.3.3.83)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r requirements.txt (line 4)) (1.13.1.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r requirements.txt (line 4)) (12.8.90)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r requirements.txt (line 4)) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r requirements.txt (line 4)) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r requirements.txt (line 4)) (12.5.8.93)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r requirements.txt (line 4)) (12.8.93)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r requirements.txt (line 4)) (12.8.93)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r requirements.txt (line 4)) (12.8.90)
# Collecting trampoline>=0.1.2 (from torchsde->-r requirements.txt (line 5))
#   Downloading trampoline-0.1.2-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: huggingface-hub<2.0,>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.50.3->-r requirements.txt (line 10)) (1.23.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.50.3->-r requirements.txt (line 10)) (26.2)
# Requirement already satisfied: regex>=2025.10.22 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.50.3->-r requirements.txt (line 10)) (2025.11.3)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from transformers>=4.50.3->-r requirements.txt (line 10)) (0.26.8)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.11.8->-r requirements.txt (line 14)) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.11.8->-r requirements.txt (line 14)) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.11.8->-r requirements.txt (line 14)) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.11.8->-r requirements.txt (line 14)) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.11.8->-r requirements.txt (line 14)) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.11.8->-r requirements.txt (line 14)) (0.5.2)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.12/dist-packages (from yarl>=1.18.0->-r requirements.txt (line 15)) (3.18)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic->-r requirements.txt (line 21)) (1.1.3)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from SQLAlchemy>=2.0.0->-r requirements.txt (line 22)) (3.5.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->-r requirements.txt (line 27)) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->-r requirements.txt (line 27)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->-r requirements.txt (line 27)) (2026.6.17)
# Collecting kornia-rs>=0.1.9 (from kornia>=0.7.1->-r requirements.txt (line 32))
#   Downloading kornia_rs-0.1.14-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (15 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic~=2.0->-r requirements.txt (line 34)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.12/dist-packages (from pydantic~=2.0->-r requirements.txt (line 34)) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic~=2.0->-r requirements.txt (line 34)) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from pydantic-settings~=2.0->-r requirements.txt (line 35)) (1.2.2)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings<13,>=12.9.4->torch->-r requirements.txt (line 4)) (1.5.6)
# Requirement already satisfied: click<9.0.0,>=8.4.2 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers>=4.50.3->-r requirements.txt (line 10)) (8.4.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers>=4.50.3->-r requirements.txt (line 10)) (1.5.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers>=4.50.3->-r requirements.txt (line 10)) (0.28.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->-r requirements.txt (line 4)) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->-r requirements.txt (line 4)) (3.0.3)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->transformers>=4.50.3->-r requirements.txt (line 10)) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /usr/local/lib/python3.12/dist-packages (from typer->transformers>=4.50.3->-r requirements.txt (line 10)) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->transformers>=4.50.3->-r requirements.txt (line 10)) (0.0.4)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers>=4.50.3->-r requirements.txt (line 10)) (4.14.2)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers>=4.50.3->-r requirements.txt (line 10)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers>=4.50.3->-r requirements.txt (line 10)) (0.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer->transformers>=4.50.3->-r requirements.txt (line 10)) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer->transformers>=4.50.3->-r requirements.txt (line 10)) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer->transformers>=4.50.3->-r requirements.txt (line 10)) (0.1.2)
# Downloading comfyui_frontend_package-1.45.21-py3-none-any.whl (26.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.7/26.7 MB 21.3 MB/s eta 0:00:00
# Downloading comfyui_workflow_templates-0.11.12-py3-none-any.whl (10 kB)
# Downloading comfyui_embedded_docs-0.5.8-py3-none-any.whl (15.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.5/15.5 MB 115.7 MB/s eta 0:00:00
# Downloading comfy_kitchen-0.2.22-cp312-abi3-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (29.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.4/29.4 MB 79.0 MB/s eta 0:00:00
# Downloading comfy_aimdo-0.4.10-cp39-abi3-manylinux2010_x86_64.manylinux2014_x86_64.manylinux_2_12_x86_64.manylinux_2_17_x86_64.whl (346 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 346.8/346.8 kB 35.3 MB/s eta 0:00:00
# Downloading comfyui_workflow_templates_core-0.3.275-py3-none-any.whl (65 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.4/65.4 kB 7.6 MB/s eta 0:00:00
# Downloading comfyui_workflow_templates_json-0.1.9-py3-none-any.whl (2.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 123.8 MB/s eta 0:00:00
# Downloading comfyui_workflow_templates_media_api-0.3.84-py3-none-any.whl (100.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.1/100.1 MB 8.3 MB/s eta 0:00:00
# Downloading comfyui_workflow_templates_media_assets_01-0.1.5-py3-none-any.whl (14.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 110.7 MB/s eta 0:00:00
# Downloading comfyui_workflow_templates_media_image-0.3.160-py3-none-any.whl (89.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.4/89.4 MB 9.2 MB/s eta 0:00:00
# Downloading comfyui_workflow_templates_media_other-0.3.229-py3-none-any.whl (89.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.1/89.1 MB 9.1 MB/s eta 0:00:00
# Downloading comfyui_workflow_templates_media_video-0.3.101-py3-none-any.whl (104.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.3/104.3 MB 8.9 MB/s eta 0:00:00
# Downloading torchsde-0.2.6-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 6.6 MB/s eta 0:00:00
# Downloading alembic-1.18.5-py3-none-any.whl (264 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.7/264.7 kB 25.9 MB/s eta 0:00:00
# Downloading av-18.0.0-cp311-abi3-manylinux_2_28_x86_64.whl (35.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.5/35.5 MB 27.0 MB/s eta 0:00:00
# Downloading simpleeval-1.0.7-py3-none-any.whl (18 kB)
# Downloading blake3-1.0.9-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (383 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 383.9/383.9 kB 20.2 MB/s eta 0:00:00
# Downloading kornia-0.8.3-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 27.2 MB/s eta 0:00:00
# Downloading spandrel-0.4.2-py3-none-any.whl (320 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 320.8/320.8 kB 28.2 MB/s eta 0:00:00
# Downloading pydantic_settings-2.14.2-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.7/61.7 kB 5.2 MB/s eta 0:00:00
# Downloading comfy_angle-0.1.0-py3-none-manylinux_2_28_x86_64.whl (4.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 36.0 MB/s eta 0:00:00
# Downloading kornia_rs-0.1.14-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 36.8 MB/s eta 0:00:00
# Downloading trampoline-0.1.2-py3-none-any.whl (5.2 kB)
# Installing collected packages: trampoline, simpleeval, kornia-rs, comfyui-workflow-templates-media-video, comfyui-workflow-templates-media-other, comfyui-workflow-templates-media-image, comfyui-workflow-templates-media-assets-01, comfyui-workflow-templates-media-api, comfyui-workflow-templates-json, comfyui-workflow-templates-core, comfyui-frontend-package, comfyui-embedded-docs, comfy-kitchen, comfy-angle, comfy-aimdo, blake3, av, comfyui-workflow-templates, alembic, pydantic-settings, torchsde, kornia, spandrel
# Successfully installed alembic-1.18.5 av-18.0.0 blake3-1.0.9 comfy-aimdo-0.4.10 comfy-angle-0.1.0 comfy-kitchen-0.2.22 comfyui-embedded-docs-0.5.8 comfyui-frontend-package-1.45.21 comfyui-workflow-templates-0.11.12 comfyui-workflow-templates-core-0.3.275 comfyui-workflow-templates-json-0.1.9 comfyui-workflow-templates-media-api-0.3.84 comfyui-workflow-templates-media-assets-01-0.1.5 comfyui-workflow-templates-media-image-0.3.160 comfyui-workflow-templates-media-other-0.3.229 comfyui-workflow-templates-media-video-0.3.101 kornia-0.8.3 kornia-rs-0.1.14 pydantic-settings-2.14.2 simpleeval-1.0.7 spandrel-0.4.2 torchsde-0.2.6 trampoline-0.1.2

# %%
# Install the pinggy library for creating public URLs
# !pip install pinggy
# Out:
# Collecting pinggy
#   Downloading pinggy-0.3.0-cp36-abi3-manylinux_2_28_x86_64.whl.metadata (2.9 kB)
# Downloading pinggy-0.3.0-cp36-abi3-manylinux_2_28_x86_64.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 115.4 MB/s eta 0:00:00
# Installing collected packages: pinggy
# Successfully installed pinggy-0.3.0

# %%
# Clone ComfyUI custom nodes
# Install ComfyUI custom nodes
import pathlib, subprocess

root = pathlib.Path("/content/ComfyUI")
custom = root / "custom_nodes"
custom.mkdir(parents=True, exist_ok=True)

# %cd /content/ComfyUI/custom_nodes

repos = [
    "https://github.com/Alectriciti/comfyui-adaptiveprompts.git",
    "https://github.com/scottmudge/ComfyUI-NAG.git",
    "https://github.com/melMass/comfy_mtb.git",
    "https://github.com/rgthree/rgthree-comfy.git",
    "https://github.com/kijai/ComfyUI-WanVideoWrapper.git",
    "https://github.com/Kosinkadink/ComfyUI-VideoHelperSuite.git",
    "https://github.com/Fannovel16/ComfyUI-Frame-Interpolation.git",
    "https://github.com/kijai/ComfyUI-KJNodes.git",
    "https://github.com/yolain/ComfyUI-Easy-Use.git",
    "https://github.com/Suzie1/ComfyUI_Comfyroll_CustomNodes.git",
    "https://github.com/city96/ComfyUI-GGUF.git",
    "https://github.com/Smirnov75/ComfyUI-mxToolkit.git",
    "https://github.com/Comfy-Org/ComfyUI-Manager.git"
]

# Клонирование
for url in repos:
    name = url.rsplit("/", 1)[-1].replace(".git", "")
    if (custom / name).exists():
        print(f"Skip, already exists: {name}")
        continue
    subprocess.run(["git", "clone", url], check=True)

# Установка requirements (если есть)
for url in repos:
    name = url.rsplit("/", 1)[-1].replace(".git", "")
    req = custom / name / "requirements.txt"
    if req.exists():
        print(f"Installing requirements for {name}")
        subprocess.run(["pip", "install", "-r", str(req)], check=True)
    else:
        print(f"No requirements.txt for {name}, skip")
# Out:
# /content/ComfyUI/custom_nodes
# No requirements.txt for comfyui-adaptiveprompts, skip
# No requirements.txt for ComfyUI-NAG, skip
# Installing requirements for comfy_mtb
# Installing requirements for rgthree-comfy
# Installing requirements for ComfyUI-WanVideoWrapper
# Installing requirements for ComfyUI-VideoHelperSuite
# No requirements.txt for ComfyUI-Frame-Interpolation, skip
# Installing requirements for ComfyUI-KJNodes
# Installing requirements for ComfyUI-Easy-Use
# No requirements.txt for ComfyUI_Comfyroll_CustomNodes, skip
# Installing requirements for ComfyUI-GGUF
# No requirements.txt for ComfyUI-mxToolkit, skip

# %%
# Download Wan / GGUF / LoRA models for ComfyUI (Civitai через ?token=)

import os
import pathlib
import subprocess
from urllib.parse import urlparse, parse_qs, urlencode, urlunparse
from google.colab import userdata

# Берём токен из окружения (Colab Secrets / Variables)
#CIVITAI_TOKEN = os.environ.get("CIVITAI_TOKEN", "").strip()
CIVITAI_TOKEN = userdata.get("CIVITAI_TOKEN").strip()
if not CIVITAI_TOKEN:
    print("WARNING: CIVITAI_TOKEN не найден в os.environ – ссылки Civitai, требующие логин, могут не скачаться.")

root = pathlib.Path("/content/ComfyUI")

paths = {
    "vae": root / "models" / "vae",
    "text_encoders": root / "models" / "text_encoders",
    "diffusion": root / "models" / "diffusion_models",
    "loras": root / "models" / "loras",
    "clip_vision": root / "models" / "clip_vision",
    "upscale_models": root / "models" / "upscale_models",
}

for p in paths.values():
    p.mkdir(parents=True, exist_ok=True)

downloads = [
    # Wan VAE
    (
        "https://huggingface.co/OreX/Models/resolve/main/WAN/wan_2.1_vae.safetensors?download=true",
        paths["vae"] / "wan_2.1_vae.safetensors",
    ),
    # umt5 text encoder
    (
        "https://huggingface.co/OreX/Models/resolve/main/WAN/umt5_xxl_fp8_e4m3fn_scaled.safetensors?download=true",
        paths["text_encoders"] / "umt5_xxl_fp8_e4m3fn_scaled.safetensors",
    ),
    # Smooth Mix Wan 2.2 14B I2V 2.0 High (Civitai)
    (
        "https://civitai.red/api/download/models/2513182?fileId=2460270",
        paths["diffusion"] / "SmoothMix_Wan2.2_14B_I2V_2.0_High.safetensors",
    ),
    # Smooth Mix Wan 2.2 14B I2V 2.0 Low (Civitai)
    (
        "https://civitai.red/api/download/models/2513186?fileId=2460676",
        paths["diffusion"] / "SmoothMix_Wan2.2_14B_I2V_2.0_Low.safetensors",
    ),
    # GGUF High
    (
        "https://huggingface.co/QuantStack/Wan2.2-I2V-A14B-GGUF/resolve/main/HighNoise/Wan2.2-I2V-A14B-HighNoise-Q2_K.gguf?download=true",
        paths["diffusion"] / "Wan2.2-I2V-A14B-HighNoise-Q2_K.gguf",
    ),
    # GGUF Low
    (
        "https://huggingface.co/QuantStack/Wan2.2-I2V-A14B-GGUF/resolve/main/LowNoise/Wan2.2-I2V-A14B-LowNoise-Q2_K.gguf?download=true",
        paths["diffusion"] / "Wan2.2-I2V-A14B-LowNoise-Q2_K.gguf",
    ),
    # LoRA lightx2v
    (
        "https://huggingface.co/Kijai/WanVideo_comfy/resolve/709844db75d2e15582cf204e9a0b5e12b23a35dd/Lightx2v/lightx2v_I2V_14B_480p_cfg_step_distill_rank128_bf16.safetensors?download=true",
        paths["loras"] / "lightx2v_I2V_14B_480p_cfg_step_distill_rank128_bf16.safetensors",
    ),
    # clip_vision
    (
        "https://huggingface.co/OreX/Models/resolve/main/WAN/clip_vision_h.safetensors?download=true",
        paths["clip_vision"] / "clip_vision_h.safetensors",
    ),
    # upscale models
    (
        "https://huggingface.co/utnah/esrgan/resolve/main/4x-AnimeSharp.pth?download=true",
        paths["upscale_models"] / "4x-AnimeSharp.pth",
    ),
]

def add_token_to_civitai_url(url: str, token: str) -> str:
    if not token:
        return url
    if "civitai.com" not in url and "civitai.red" not in url:
        return url

    parsed = urlparse(url)
    qs = parse_qs(parsed.query)
    # не перезаписываем, если токен уже вставлен руками
    if "token" in qs:
        return url

    qs["token"] = [token]
    new_query = urlencode(qs, doseq=True)
    new_parsed = parsed._replace(query=new_query)
    return urlunparse(new_parsed)

def build_aria2_cmd(url: str, out_path: pathlib.Path):
    # Для civitai добавляем token в сам URL
    url_with_token = add_token_to_civitai_url(url, CIVITAI_TOKEN)

    cmd = [
        "aria2c",
        "-x", "16",
        "-s", "16",
        "-o", out_path.name,
        "-d", str(out_path.parent),
        url_with_token,
    ]
    return cmd

for url, out_path in downloads:
    if out_path.exists():
        print(f"Already exists, skip: {out_path}")
        continue

    out_path.parent.mkdir(parents=True, exist_ok=True)
    print(f"\nDownloading {url} -> {out_path}")

    cmd = build_aria2_cmd(url, out_path)
    print("Command:", " ".join(cmd))
    try:
        # Важно: для ссылок с '&' aria2c уже видит всё как один аргумент,
        # т.к. мы не даём shell и передаём список аргументов subprocess-у.
        subprocess.run(cmd, check=True)
    except subprocess.CalledProcessError as e:
        print(f"Download failed for {url}: {e}")
# Out:
# Downloading https://huggingface.co/OreX/Models/resolve/main/WAN/wan_2.1_vae.safetensors?download=true -> /content/ComfyUI/models/vae/wan_2.1_vae.safetensors
# Command: aria2c -x 16 -s 16 -o wan_2.1_vae.safetensors -d /content/ComfyUI/models/vae https://huggingface.co/OreX/Models/resolve/main/WAN/wan_2.1_vae.safetensors?download=true
#
# Downloading https://huggingface.co/OreX/Models/resolve/main/WAN/umt5_xxl_fp8_e4m3fn_scaled.safetensors?download=true -> /content/ComfyUI/models/text_encoders/umt5_xxl_fp8_e4m3fn_scaled.safetensors
# Command: aria2c -x 16 -s 16 -o umt5_xxl_fp8_e4m3fn_scaled.safetensors -d /content/ComfyUI/models/text_encoders https://huggingface.co/OreX/Models/resolve/main/WAN/umt5_xxl_fp8_e4m3fn_scaled.safetensors?download=true
#
# Downloading https://civitai.red/api/download/models/2513182?fileId=2460270 -> /content/ComfyUI/models/diffusion_models/SmoothMix_Wan2.2_14B_I2V_2.0_High.safetensors
# Command: aria2c -x 16 -s 16 -o SmoothMix_Wan2.2_14B_I2V_2.0_High.safetensors -d /content/ComfyUI/models/diffusion_models https://civitai.red/api/download/models/2513182?fileId=2460270&token=cb2721923059a011c1fce7556e35751a
#
# Downloading https://civitai.red/api/download/models/2513186?fileId=2460676 -> /content/ComfyUI/models/diffusion_models/SmoothMix_Wan2.2_14B_I2V_2.0_Low.safetensors
# Command: aria2c -x 16 -s 16 -o SmoothMix_Wan2.2_14B_I2V_2.0_Low.safetensors -d /content/ComfyUI/models/diffusion_models https://civitai.red/api/download/models/2513186?fileId=2460676&token=cb2721923059a011c1fce7556e35751a
#
# Downloading https://huggingface.co/QuantStack/Wan2.2-I2V-A14B-GGUF/resolve/main/HighNoise/Wan2.2-I2V-A14B-HighNoise-Q2_K.gguf?download=true -> /content/ComfyUI/models/diffusion_models/Wan2.2-I2V-A14B-HighNoise-Q2_K.gguf
# Command: aria2c -x 16 -s 16 -o Wan2.2-I2V-A14B-HighNoise-Q2_K.gguf -d /content/ComfyUI/models/diffusion_models https://huggingface.co/QuantStack/Wan2.2-I2V-A14B-GGUF/resolve/main/HighNoise/Wan2.2-I2V-A14B-HighNoise-Q2_K.gguf?download=true
#
# Downloading https://huggingface.co/QuantStack/Wan2.2-I2V-A14B-GGUF/resolve/main/LowNoise/Wan2.2-I2V-A14B-LowNoise-Q2_K.gguf?download=true -> /content/ComfyUI/models/diffusion_models/Wan2.2-I2V-A14B-LowNoise-Q2_K.gguf
# Command: aria2c -x 16 -s 16 -o Wan2.2-I2V-A14B-LowNoise-Q2_K.gguf -d /content/ComfyUI/models/diffusion_models https://huggingface.co/QuantStack/Wan2.2-I2V-A14B-GGUF/resolve/main/LowNoise/Wan2.2-I2V-A14B-LowNoise-Q2_K.gguf?download=true
#
# Downloading https://huggingface.co/Kijai/WanVideo_comfy/resolve/709844db75d2e15582cf204e9a0b5e12b23a35dd/Lightx2v/lightx2v_I2V_14B_480p_cfg_step_distill_rank128_bf16.safetensors?download=true -> /content/ComfyUI/models/loras/lightx2v_I2V_14B_480p_cfg_step_distill_rank128_bf16.safetensors
# Command: aria2c -x 16 -s 16 -o lightx2v_I2V_14B_480p_cfg_step_distill_rank128_bf16.safetensors -d /content/ComfyUI/models/loras https://huggingface.co/Kijai/WanVideo_comfy/resolve/709844db75d2e15582cf204e9a0b5e12b23a35dd/Lightx2v/lightx2v_I2V_14B_480p_cfg_step_distill_rank128_bf16.safetensors?download=true
#
# Downloading https://huggingface.co/OreX/Models/resolve/main/WAN/clip_vision_h.safetensors?download=true -> /content/ComfyUI/models/clip_vision/clip_vision_h.safetensors
# Command: aria2c -x 16 -s 16 -o clip_vision_h.safetensors -d /content/ComfyUI/models/clip_vision https://huggingface.co/OreX/Models/resolve/main/WAN/clip_vision_h.safetensors?download=true
#
# Downloading https://huggingface.co/utnah/esrgan/resolve/main/4x-AnimeSharp.pth?download=true -> /content/ComfyUI/models/upscale_models/4x-AnimeSharp.pth
# Command: aria2c -x 16 -s 16 -o 4x-AnimeSharp.pth -d /content/ComfyUI/models/upscale_models https://huggingface.co/utnah/esrgan/resolve/main/4x-AnimeSharp.pth?download=true

# %%
# Start a pinggy tunnel to forward traffic from a public URL to localhost:8188
import pinggy
tunnel1 = pinggy.start_tunnel(
    forwardto="localhost:8188",
)

# Print the URLs of the started tunnel
print(f"Tunnel1 started - URLs: {tunnel1.urls}")
# Out:
# Tunnel1 started - URLs: ['https://revkf-34-142-216-138.free.pinggy.net', 'https://uxtpb-34-142-216-138.run.pinggy-free.link']

# %%
# Run the main ComfyUI application, listening on all network interfaces
# %cd /content/ComfyUI
# !nohup python main.py --listen 0.0.0.0 > comfyui.log 2>&1 &
# Out:
# /content/ComfyUI

# %%
# %cd /content/
# !wget https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64 -O cloudflared
# !chmod +x cloudflared
# !ls -l cloudflared
# !chmod +x cloudflared
# !./cloudflared --version
# !nohup ./cloudflared tunnel --url http://127.0.0.1:8188 --no-autoupdate > /content/cloudflared.log 2>&1 &
# Out:
# /content
# --2026-07-22 13:18:46--  https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64
# Resolving github.com (github.com)... 140.82.114.4
# Connecting to github.com (github.com)|140.82.114.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/cloudflare/cloudflared/releases/download/2026.7.2/cloudflared-linux-amd64 [following]
# --2026-07-22 13:18:46--  https://github.com/cloudflare/cloudflared/releases/download/2026.7.2/cloudflared-linux-amd64
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://release-assets.githubusercontent.com/github-production-release-asset/106867604/5b9ae8f6-6458-4c0c-afbf-ebcf7b113206?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-07-22T14%3A05%3A38Z&rscd=attachment%3B+filename%3Dcloudflared-linux-amd64&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-07-22T13%3A05%3A37Z&ske=2026-07-22T14%3A05%3A38Z&sks=b&skv=2018-11-09&sig=Y05QQKNcWJpJaojRc%2FbxwRVaU8mem%2Ba%2Fvs1iqBcY6Ok%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc4NDcyODAxNSwibmJmIjoxNzg0NzI2MjE1LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.X68BHjGtAzPUkgQwf-CHHY24pKQqwDyBb2UKzrfoock&response-content-disposition=attachment%3B%20filename%3Dcloudflared-linux-amd64&response-content-type=application%2Foctet-stream [following]
# --2026-07-22 13:18:46--  https://release-assets.githubusercontent.com/github-production-release-asset/106867604/5b9ae8f6-6458-4c0c-afbf-ebcf7b113206?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-07-22T14%3A05%3A38Z&rscd=attachment%3B+filename%3Dcloudflared-linux-amd64&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-07-22T13%3A05%3A37Z&ske=2026-07-22T14%3A05%3A38Z&sks=b&skv=2018-11-09&sig=Y05QQKNcWJpJaojRc%2FbxwRVaU8mem%2Ba%2Fvs1iqBcY6Ok%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc4NDcyODAxNSwibmJmIjoxNzg0NzI2MjE1LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.X68BHjGtAzPUkgQwf-CHHY24pKQqwDyBb2UKzrfoock&response-content-disposition=attachment%3B%20filename%3Dcloudflared-linux-amd64&response-content-type=application%2Foctet-stream
# Resolving release-assets.githubusercontent.com (release-assets.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to release-assets.githubusercontent.com (release-assets.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 39261733 (37M) [application/octet-stream]
# Saving to: ‘cloudflared’
#
# cloudflared         100%[===================>]  37.44M   211MB/s    in 0.2s
#
# 2026-07-22 13:18:46 (211 MB/s) - ‘cloudflared’ saved [39261733/39261733]
#
# -rwxr-xr-x 1 root root 39261733 Jul 15 13:36 cloudflared
# cloudflared version 2026.7.2 (built 2026-07-15-13:29 UTC)

# %%
# !grep -o 'https://[^ ]*trycloudflare.com' cloudflared.log
# Out:
# https://whilst-attraction-lives-bras.trycloudflare.com
